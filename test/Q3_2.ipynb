# %%
import pandas as pd
import warnings
from sklearn.metrics import r2_score
warnings.filterwarnings('ignore')

# %%
data=pd.read_excel('附件14不同放牧强度土壤碳氮监测数据.xlsx')
data.head()
# Out:
#    year 放牧小区（plot） 放牧强度（intensity）   SOC土壤有机碳   SIC土壤无机碳    STC土壤全碳       全氮N  \
# 0  2012        G17              NG  17.051564  11.300000  28.351564  2.192376
# 1  2012        G19              NG  19.529439  11.333333  30.862772  1.883051
# 2  2012        G21              NG  14.549908   9.600000  24.149908  1.871001
# 3  2012         G6             LGI  18.672931  12.666667  31.339598  2.407612
# 4  2012        G12             LGI  13.904905   8.133333  22.038239  1.933916
#
#       土壤C/N比
# 0  12.931887
# 1  16.389768
# 2  13.818022
# 3  12.160230
# 4  11.395652

# %%
data
# Out:
#      year 放牧小区（plot） 放牧强度（intensity）   SOC土壤有机碳   SIC土壤无机碳    STC土壤全碳  \
# 0    2012        G17              NG  17.051564  11.300000  28.351564
# 1    2012        G19              NG  19.529439  11.333333  30.862772
# 2    2012        G21              NG  14.549908   9.600000  24.149908
# 3    2012         G6             LGI  18.672931  12.666667  31.339598
# 4    2012        G12             LGI  13.904905   8.133333  22.038239
# ..    ...        ...             ...        ...        ...        ...
# 127  2020        G11             MGI  14.744350   3.353600  18.097950
# 128  2020        G16             MGI  14.777000   9.819450  24.596450
# 129  2020         G9             HGI  17.200000   3.122150  20.322150
# 130  2020        G13             HGI  16.691900   3.564700  20.256600
# 131  2020        G20             HGI  15.969600   4.657050  20.626650
#
#           全氮N     土壤C/N比
# 0    2.192376  12.931887
# 1    1.883051  16.389768
# 2    1.871001  13.818022
# 3    2.407612  12.160230
# 4    1.933916  11.395652
# ..        ...        ...
# 127  1.961450   9.226822
# 128  1.712250  14.364988
# 129  2.236950   9.084758
# 130  2.102850   9.632927
# 131  2.054600  10.039253
#
# [132 rows x 8 columns]

# %%
temp2=pd.read_excel('附件3、土壤湿度2022—2012年.xls')
temp3=pd.read_excel('附件4、土壤蒸发量2012—2022年.xls')
temp4=pd.read_excel('附件6、植被指数-NDVI2012-2022年.xls')
temp5=pd.read_excel('附件9、径流量2012-2022年.xlsx')
tempdf=pd.merge(temp2,temp3)
tempdf=pd.merge(tempdf,temp4)
tempdf=pd.merge(tempdf,temp5)

# %%
df=pd.merge(tempdf,data,left_on=['年份'],right_on='year')

# %%
df
# Out:
#       月份    年份  经度(lon)  纬度(lat)  10cm湿度(kg/m2)  40cm湿度(kg/m2)  \
# 0      1  2020  115.375   44.125          12.21          33.85
# 1      1  2020  115.375   44.125          12.21          33.85
# 2      1  2020  115.375   44.125          12.21          33.85
# 3      1  2020  115.375   44.125          12.21          33.85
# 4      1  2020  115.375   44.125          12.21          33.85
# ...   ..   ...      ...      ...            ...            ...
# 1579  12  2012  115.375   44.125          14.42          42.71
# 1580  12  2012  115.375   44.125          14.42          42.71
# 1581  12  2012  115.375   44.125          14.42          42.71
# 1582  12  2012  115.375   44.125          14.42          42.71
# 1583  12  2012  115.375   44.125          14.42          42.71
#
#       100cm湿度(kg/m2)  200cm湿度(kg/m2)  土壤蒸发量(W/m2)  土壤蒸发量(mm)  ...  径流量(m3/s)  \
# 0              47.07          166.70         0.33       0.36  ...   0.021169
# 1              47.07          166.70         0.33       0.36  ...   0.021169
# 2              47.07          166.70         0.33       0.36  ...   0.021169
# 3              47.07          166.70         0.33       0.36  ...   0.021169
# 4              47.07          166.70         0.33       0.36  ...   0.021169
# ...              ...             ...          ...        ...  ...        ...
# 1579           55.02          168.32         0.32       0.34  ...   0.213710
# 1580           55.02          168.32         0.32       0.34  ...   0.213710
# 1581           55.02          168.32         0.32       0.34  ...   0.213710
# 1582           55.02          168.32         0.32       0.34  ...   0.213710
# 1583           55.02          168.32         0.32       0.34  ...   0.213710
#
#        径流量(m3)  year  放牧小区（plot） 放牧强度（intensity）   SOC土壤有机碳   SIC土壤无机碳  \
# 0      56700.0  2020         G17              NG  16.858300   6.086750
# 1      56700.0  2020         G19              NG  17.298500   4.301450
# 2      56700.0  2020         G21              NG  20.133500   4.064900
# 3      56700.0  2020          G6             LGI  14.789650   3.001200
# 4      56700.0  2020         G12             LGI  16.185800   3.802900
# ...        ...   ...         ...             ...        ...        ...
# 1579  572400.0  2012         G11             MGI  11.540390  10.600000
# 1580  572400.0  2012         G16             MGI   9.023189  14.000000
# 1581  572400.0  2012          G9             HGI  13.044162   8.750000
# 1582  572400.0  2012         G13             HGI   9.084952  10.750000
# 1583  572400.0  2012         G20             HGI   9.960078  14.483333
#
#         STC土壤全碳       全氮N     土壤C/N比
# 0     22.945050  2.115200  10.847698
# 1     21.599950  2.198050   9.826869
# 2     24.198400  2.431150   9.953479
# 3     17.790850  2.016500   8.822638
# 4     19.988700  1.944800  10.278023
# ...         ...       ...        ...
# 1579  22.140390  1.439160  15.384246
# 1580  23.023189  1.531216  15.035882
# 1581  21.794162  1.226313  17.772109
# 1582  19.834952  1.083022  18.314458
# 1583  24.443412  1.410979  17.323723
#
# [1584 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['月份', '年份', '经度(lon)', '纬度(lat)', '10cm湿度(kg/m2)', '40cm湿度(kg/m2)',
#        '100cm湿度(kg/m2)', '200cm湿度(kg/m2)', '土壤蒸发量(W/m2)', '土壤蒸发量(mm)',
#        '植被指数(NDVI)', '径流量(m3/s)', '径流量(m3)', 'year', '放牧小区（plot）',
#        '放牧强度（intensity）', 'SOC土壤有机碳', 'SIC土壤无机碳', 'STC土壤全碳', '全氮N', '土壤C/N比'],
#       dtype='object')

# %%
DF=df[['月份', '年份','放牧强度（intensity）', '10cm湿度(kg/m2)', '40cm湿度(kg/m2)',
       '100cm湿度(kg/m2)', '200cm湿度(kg/m2)', '土壤蒸发量(W/m2)', '土壤蒸发量(mm)',
       '植被指数(NDVI)', '径流量(m3/s)', '径流量(m3)', 'year', '放牧小区（plot）',
        'SOC土壤有机碳', 'SIC土壤无机碳', 'STC土壤全碳', '全氮N', '土壤C/N比']]

# %%
df.to_csv('Q3-2.df.csv')

# %%
temp=DF[(DF['放牧小区（plot）']=='G17')&(DF['放牧强度（intensity）']=='NG')]
temp.reset_index(inplace=True,drop=True)
temp
# Out:
#      月份    年份 放牧强度（intensity）  10cm湿度(kg/m2)  40cm湿度(kg/m2)  100cm湿度(kg/m2)  \
# 0     1  2020              NG          12.21          33.85           47.07
# 1     2  2020              NG          11.86          33.85           47.07
# 2     3  2020              NG          11.95          33.84           47.07
# 3     4  2020              NG          13.73          33.65           46.99
# 4     5  2020              NG          16.51          34.02           46.68
# ..   ..   ...             ...            ...            ...             ...
# 127  10  2012              NG          15.04          42.49           54.69
# 128  11  2012              NG          14.79          42.71           55.02
# 129  11  2012              NG          14.79          42.71           55.02
# 130  12  2012              NG          14.42          42.71           55.02
# 131  12  2012              NG          14.42          42.71           55.02
#
#      200cm湿度(kg/m2)  土壤蒸发量(W/m2)  土壤蒸发量(mm)  植被指数(NDVI)  径流量(m3/s)  \
# 0            166.70         0.33       0.36      -0.009   0.021169
# 1            166.70         0.63       0.63       0.002   0.000000
# 2            166.70         2.60       2.78       0.187   0.979839
# 3            166.70        10.51      10.89       0.176   0.177083
# 4            166.70        19.89      21.31       0.187   0.132056
# ..              ...          ...        ...         ...        ...
# 127          168.33         7.59       8.13       0.282   0.361643
# 128          168.32         0.88       0.92       0.176   0.290104
# 129          168.32         0.88       0.92       0.176   0.290104
# 130          168.32         0.32       0.34       0.018   0.213710
# 131          168.32         0.32       0.34       0.018   0.213710
#
#         径流量(m3)  year 放牧小区（plot）   SOC土壤有机碳  SIC土壤无机碳    STC土壤全碳       全氮N  \
# 0      56700.00  2020        G17  16.858300   6.08675  22.945050  2.115200
# 1          0.00  2020        G17  16.858300   6.08675  22.945050  2.115200
# 2    2624400.00  2020        G17  16.858300   6.08675  22.945050  2.115200
# 3     459000.00  2020        G17  16.858300   6.08675  22.945050  2.115200
# 4     353700.00  2020        G17  16.858300   6.08675  22.945050  2.115200
# ..          ...   ...        ...        ...       ...        ...       ...
# 127   968624.94  2012        G17  10.895523  10.60000  21.495523  1.125775
# 128   751950.00  2012        G17  17.051564  11.30000  28.351564  2.192376
# 129   751950.00  2012        G17  10.895523  10.60000  21.495523  1.125775
# 130   572400.00  2012        G17  17.051564  11.30000  28.351564  2.192376
# 131   572400.00  2012        G17  10.895523  10.60000  21.495523  1.125775
#
#         土壤C/N比
# 0    10.847698
# 1    10.847698
# 2    10.847698
# 3    10.847698
# 4    10.847698
# ..         ...
# 127  19.093970
# 128  12.931887
# 129  19.093970
# 130  12.931887
# 131  19.093970
#
# [132 rows x 19 columns]

# %%
temp.groupby('年份').mean()
# Out:
#        月份  10cm湿度(kg/m2)  40cm湿度(kg/m2)  100cm湿度(kg/m2)  200cm湿度(kg/m2)  \
# 年份
# 2012  6.5      15.127500      38.903333       49.407500      168.473333
# 2014  6.5      14.151667      37.987500       50.033333      167.867500
# 2016  6.5      14.746667      42.928333       46.701667      167.461667
# 2018  6.5      14.180833      41.373333       50.712500      167.205000
# 2020  6.5      16.129167      44.420833       60.470000      166.465000
#
#       土壤蒸发量(W/m2)  土壤蒸发量(mm)  植被指数(NDVI)  径流量(m3/s)        径流量(m3)    year  \
# 年份
# 2012    10.312500  10.892500    0.247750   0.369462  978637.503333  2012.0
# 2014    11.260833  11.897500    0.258583   0.247870  655650.005000  2014.0
# 2016     8.950833   9.459167    0.203917   0.277649  736481.250000  2016.0
# 2018     8.682500   9.176667    0.276000   0.339387  896343.753333  2018.0
# 2020    11.865000  12.555000    0.265167   0.225629  598781.250000  2020.0
#
#        SOC土壤有机碳   SIC土壤无机碳    STC土壤全碳       全氮N     土壤C/N比
# 年份
# 2012  13.973544  10.950000  24.923544  1.659076  16.012928
# 2014  13.747096  11.100000  24.847096  1.641051  15.823591
# 2016  15.679023   7.983333  23.662356  1.813318  14.102624
# 2018  15.763244   7.833333  23.596577  1.971321  12.858514
# 2020  16.858300   6.086750  22.945050  2.115200  10.847698

# %%
temp=temp.groupby('年份').mean()
temp.reset_index(inplace=True,drop=False)

# %%
temp.isnull().sum()
# Out:
# 年份                0
# 月份                0
# 10cm湿度(kg/m2)     0
# 40cm湿度(kg/m2)     0
# 100cm湿度(kg/m2)    0
# 200cm湿度(kg/m2)    0
# 土壤蒸发量(W/m2)       0
# 土壤蒸发量(mm)         0
# 植被指数(NDVI)        0
# 径流量(m3/s)         0
# 径流量(m3)           0
# year              0
# SOC土壤有机碳          0
# SIC土壤无机碳          0
# STC土壤全碳           0
# 全氮N               0
# 土壤C/N比            0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.models import Sequential, load_model
np.set_printoptions(suppress=True)
# %matplotlib inline

from sklearn.preprocessing import MinMaxScaler
from pylab import *
mpl.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False 
import seaborn as sns 
sns.set_palette("husl") #设置所有图的颜色，使用hls色彩空间
import numpy as np
from sklearn import metrics
from sklearn.metrics import mean_squared_error #均方误差
from sklearn.metrics import mean_absolute_error #平方绝对误差

# %%
temp.columns
# Out:
# Index(['年份', '月份', '10cm湿度(kg/m2)', '40cm湿度(kg/m2)', '100cm湿度(kg/m2)',
#        '200cm湿度(kg/m2)', '土壤蒸发量(W/m2)', '土壤蒸发量(mm)', '植被指数(NDVI)', '径流量(m3/s)',
#        '径流量(m3)', 'year', 'SOC土壤有机碳', 'SIC土壤无机碳', 'STC土壤全碳', '全氮N', '土壤C/N比'],
#       dtype='object')

# %%
for i in [ 'SOC土壤有机碳', 'SIC土壤无机碳', 'STC土壤全碳', '全氮N', '土壤C/N比']:
    plt.plot(temp['年份'].values,temp[i].values,label=i)

plt.legend()
plt.xlabel( '年份')
plt.ylabel( '变量')
plt.title( '2012~2020 NG G17 土壤化学性质 情况')
plt.savefig('./Q3 fig/2012~2022  NG G17 土壤化学性质 情况.jpg')

# %%
dataset=temp[[ 'SOC土壤有机碳', 'SIC土壤无机碳', 'STC土壤全碳', '全氮N', '土壤C/N比','土壤蒸发量(W/m2)','土壤蒸发量(mm)']]

# %%
#########LSTM多变量模型#############
def split_sequences(sequences, n_steps):
    X, y = list(), list()
    for i in range(len(sequences)):
        end_ix = i + n_steps
        if end_ix > len(sequences)-1:
            break
        # 最关键的不一样在这一步
        seq_x, seq_y = sequences[i:end_ix, :], sequences[end_ix, :]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)
def mean_absolute_percentage_error(y_true, y_pred): 

    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def fitlstmmodel(dataset,n_steps=1):
    #dataset：数据标准化后的dataset
    # n_steps：分片大小，默认为1
    #依次为：'PM2.5','AQI',  'PM10', 'SO2', 'CO', 'NO2', 'O3_8h', '最高气温', '最低气温'

    in_seq1= dataset[:,0].reshape((dataset.shape[0], 1))
    in_seq2= dataset[:,1].reshape((dataset.shape[0], 1))
    in_seq3= dataset[:,2].reshape((dataset.shape[0], 1))
    in_seq4= dataset[:,3].reshape((dataset.shape[0], 1))
    in_seq5= dataset[:,4].reshape((dataset.shape[0], 1))
    in_seq6= dataset[:,5].reshape((dataset.shape[0], 1))
    in_seq7= dataset[:,6].reshape((dataset.shape[0], 1))
    
    dataset = np.hstack((in_seq1, in_seq2, in_seq3, in_seq4,in_seq5,in_seq6,in_seq7))
    X, y = split_sequences(dataset, n_steps)
    n_features = X.shape[2]
    model = Sequential()
    model.add(LSTM(300, activation='relu', return_sequences=True, input_shape=(n_steps, n_features)))
    model.add(LSTM(300, activation='relu'))

    # 和多对一不同点在于，这里多对多的Dense的神经元=features数目
    model.add(Dense(n_features))
    model.compile(optimizer='adam', loss='mse')
    model.fit(X, y, epochs=100, verbose=2,shuffle=False)
    model.save('lstm_model.h5')
    last_input=np.array(dataset[-1:,:])
    return X,y,last_input,n_features,n_steps

# %%
# 将整型变为float
dataset = dataset.astype('float32')
#对数据集合进行标准化
ms/step
# Epoch 73/100
# 1/1 - 0s - loss: 0.0873 - 25ms/epoch - 25ms/step
# Epoch 74/100
# 1/1 - 0s - loss: 0.0861 - 16ms/epoch - 16ms/step
# Epoch 75/100
# 1/1 - 0s - loss: 0.0849 - 44ms/epoch - 44ms/step
# Epoch 76/100
# 1/1 - 0s - loss: 0.0839 - 18ms/epoch - 18ms/step
# Epoch 77/100
# 1/1 - 0s - loss: 0.0830 - 80ms/epoch - 80ms/step
# Epoch 78/100
# 1/1 - 0s - loss: 0.0822 - 43ms/epoch - 43ms/step
# Epoch 79/100
# 1/1 - 0s - loss: 0.0816 - 40ms/epoch - 40ms/step
# Epoch 80/100
# 1/1 - 0s - loss: 0.0810 - 65ms/epoch - 65ms/step
# Epoch 81/100
# 1/1 - 0s - loss: 0.0806 - 43ms/epoch - 43ms/step
# Epoch 82/100
# 1/1 - 0s - loss: 0.0802 - 20ms/epoch - 20ms/step
# Epoch 83/100
# 1/1 - 0s - loss: 0.0799 - 17ms/epoch - 17ms/step
# Epoch 84/100
# 1/1 - 0s - loss: 0.0796 - 20ms/epoch - 20ms/step
# Epoch 85/100
# 1/1 - 0s - loss: 0.0793 - 32ms/epoch - 32ms/step
# Epoch 86/100
# 1/1 - 0s - loss: 0.0790 - 27ms/epoch - 27ms/step
# Epoch 87/100
# 1/1 - 0s - loss: 0.0786 - 25ms/epoch - 25ms/step
# Epoch 88/100
# 1/1 - 0s - loss: 0.0783 - 33ms/epoch - 33ms/step
# Epoch 89/100
# 1/1 - 0s - loss: 0.0779 - 19ms/epoch - 19ms/step
# Epoch 90/100
# 1/1 - 0s - loss: 0.0775 - 18ms/epoch - 18ms/step
# Epoch 91/100
# 1/1 - 0s - loss: 0.0770 - 20ms/epoch - 20ms/step
# Epoch 92/100
# 1/1 - 0s - loss: 0.0766 - 18ms/epoch - 18ms/step
# Epoch 93/100
# 1/1 - 0s - loss: 0.0762 - 28ms/epoch - 28ms/step
# Epoch 94/100
# 1/1 - 0s - loss: 0.0758 - 13ms/epoch - 13ms/step
# Epoch 95/100
# 1/1 - 0s - loss: 0.0754 - 14ms/epoch - 14ms/step
# Epoch 96/100
# 1/1 - 0s - loss: 0.0750 - 15ms/epoch - 15ms/step
# Epoch 97/100
# 1/1 - 0s - loss: 0.0746 - 13ms/epoch - 13ms/step
# Epoch 98/100
# 1/1 - 0s - loss: 0.0743 - 13ms/epoch - 13ms/step
# Epoch 99/100
# 1/1 - 0s - loss: 0.0739 - 16ms/epoch - 16ms/step
# Epoch 100/100
# 1/1 - 0s - loss: 0.0736 - 13ms/epoch - 13ms/step

# %%
###预测与评分
def Predict_RMSE_BA(X,y,scaler):
    model=load_model('lstm_model.h5') 
    trainPredict = model.predict(X)
    testPredict = scaler.inverse_transform(trainPredict)
    testY = scaler.inverse_transform(y)
    score(testY[:,0], testPredict[:,0])
    
    #'SOC土壤有机碳', 'SIC土壤无机碳', 'STC土壤全碳', '全氮N', '土壤C/N比'
    plt.plot(testY[:,0],color='blue', label='observed data')
    plt.plot(testPredict[:,0], color='red', label='LSTM')
    plt.xlabel( '年份')
    #'SOC土壤有机碳', 'SIC土壤无机碳', 'STC土壤全碳', '全氮N', '土壤C/N比'
    plt.ylabel( 'SOC土壤有机碳')
    plt.title( '2012~2020 NG G17 SOC土壤有机碳 情况')

    plt.legend() # 显示图例
    
    plt.savefig('./Q3 fig/2012~2020 NG G17 SOC土壤有机碳 情况.jpg')
    plt.show()
    score(testY[:,1], testPredict[:,1])
    plt.plot(testY[:,1],color='blue', label='observed data')
    plt.plot(testPredict[:,1], color='red', label='LSTM')
    plt.xlabel( '年份')
    #'SOC土壤有机碳', 'SIC土壤无机碳', 'STC土壤全碳', '全氮N', '土壤C/N比'
    plt.ylabel( 'SIC土壤无机碳')
    plt.title( '2012~2020 NG G17 SIC土壤无机碳 情况')

    plt.legend() # 显示图例

    plt.savefig('./Q3 fig/2012~2020 NG G17 SIC土壤无机碳 情况.jpg')
    plt.show()    
    score(testY[:,2], testPredict[:,2])
    plt.plot(testY[:,2],color='blue', label='observed data')
    plt.plot(testPredict[:,2], color='red', label='LSTM')
    plt.xlabel( '年份')
    #'SOC土壤有机碳', 'SIC土壤无机碳', 'STC土壤全碳', '全氮N', '土壤C/N比'
    plt.ylabel( 'STC土壤全碳')
    plt.title( '2012~2020 NG G17 STC土壤全碳 情况')

    plt.legend() # 显示图例

    plt.savefig('./Q3 fig/2012~2020 NG G17 STC土壤全碳 情况.jpg')
    plt.show()    

    score(testY[:,3], testPredict[:,3])
    plt.plot(testY[:,3],color='blue', label='observed data')
    plt.plot(testPredict[:,3], color='red', label='LSTM')
    plt.xlabel( '年份')
    #'SOC土壤有机碳', 'SIC土壤无机碳', 'STC土壤全碳', '全氮N', '土壤C/N比'
    plt.ylabel( '全氮N')
    plt.title( '2012~2020 NG G17 全氮N 情况')

    plt.legend() # 显示图例

    plt.savefig('./Q3 fig/2012~2020 NG G17 全氮N 情况.jpg')
    plt.show()
    score(testY[:,4], testPredict[:,4])
    plt.plot(testY[:,4],color='blue', label='observed data')
    plt.plot(testPredict[:,4], color='red', label='LSTM')
    plt.xlabel( '年份')
    #'SOC土壤有机碳', 'SIC土壤无机碳', 'STC土壤全碳', '全氮N', '土壤C/N比'
    plt.ylabel( '土壤C/N比')
    plt.title( '2012~2020 NG G17 土壤C/N比 情况')

    plt.legend() # 显示图例

    plt.savefig('./Q3 fig/2012~2020 NG G17 土壤CN比 情况.jpg')
    plt.show()
    
    
    return testPredict,testY
def score(y_true, y_pre):
    # MSE
    print("MAPE :")
    print(mean_absolute_percentage_error(y_true, y_pre)) 
    # RMSE
    print("RMSE :")
    print(np.sqrt(metrics.mean_squared_error(y_true, y_pre))) 
    # MAE
    print("MAE :")
    print(metrics.mean_absolute_error(y_true, y_pre)) 
    # # R2
    # print("R2 :")
    # print(np.abs(r2_score(y_true,y_pre)))
testPredict,testY=Predict_RMSE_BA(X,y,scaler)
# Out:
# 1/1 [==============================] - 1s 697ms/step
# MAPE :
# 3.691645711660385
# RMSE :
# 0.70310676
# MAE :
# 0.54727197
# MAPE :
# 12.3385488986969
# RMSE :
# 1.1966974
# MAE :
# 1.0619957
# MAPE :
# 1.679680310189724
# RMSE :
# 0.45668733
# MAE :
# 0.4035287
# MAPE :
# 2.8469670563936234
# RMSE :
# 0.065215155
# MAE :
# 0.04948607
# MAPE :
# 5.446581542491913
# RMSE :
# 0.7634598
# MAE :
# 0.7385287

# %%
def Predict_future_plot(predict_forword_number,x_input,n_features,n_steps,scaler,testPredict,testY):
    model=load_model('lstm_model.h5') 
    predict_list=[]
    predict_list.append(x_input)
    while len(predict_list) < predict_forword_number:

        x_input = predict_list[-1].reshape((-1, n_steps, n_features))
        yhat = model.predict(x_input, verbose=0)
         #预测新值
        predict_list.append(yhat)
    #取出    
    
    Predict_forword = scaler.inverse_transform(np.array([ i.reshape(-1,1)[:,0].tolist() for i in predict_list]))
    return Predict_forword[1:,:].tolist()

y_pre=Predict_future_plot(2,last_input,n_features,n_steps,scaler,testPredict,testY)
y_pre
# Out:
# [[16.658350636632207,
#   6.81933220073242,
#   23.242962500949318,
#   2.09972534913686,
#   11.827133630116569,
#   10.709867765867243,
#   11.353708860496955]]

# %%
plot='G19'
intensity='NG'
ppp=plot+' '+intensity
temp=DF[(DF['放牧小区（plot）']==plot)&(DF['放牧强度（intensity）']==intensity)]
temp.reset_index(inplace=True,drop=True)

temp=temp.groupby('年份').mean()
temp.reset_index(inplace=True,drop=False)


for i in [ 'SOC土壤有机碳', 'SIC土壤无机碳', 'STC土壤全碳', '全氮N', '土壤C/N比']:
    plt.plot(temp['年份'].values,temp[i].values,label=i)

plt.legend()
plt.xlabel( '年份')
plt.ylabel( '变量')
plt.title( '2012~2020 %s 土壤化学性质 情况'%ppp)
plt.savefig('./Q3 fig/2012~2022  %s土壤化学性质 情况.jpg'%ppp)

dataset=temp[[ 'SOC土壤有机碳', 'SIC土壤无机碳', 'STC土壤全碳', '全氮N', '土壤C/N比','土壤蒸发量(W/m2)','土壤蒸发量(mm)']]

#########LSTM多变量模型#############
def split_sequences(sequences, n_steps):
    X, y = list(), list()
    for i in range(len(sequences)):
        end_ix = i + n_steps
        if end_ix > len(sequences)-1:
            break
        # 最关键的不一样在这一步
        seq_x, seq_y = sequences[i:end_ix, :], sequences[end_ix, :]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)
def mean_absolute_percentage_error(y_true, y_pred): 

    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def fitlstmmodel(dataset,n_steps=1):
    #dataset：数据标准化后的dataset
    # n_steps：分片大小，默认为1
    #依次为：'PM2.5','AQI',  'PM10', 'SO2', 'CO', 'NO2', 'O3_8h', '最高气温', '最低气温'

    in_seq1= dataset[:,0].reshape((dataset.shape[0], 1))
    in_seq2= dataset[:,1].reshape((dataset.shape[0], 1))
    in_seq3= dataset[:,2].reshape((dataset.shape[0], 1))
    in_seq4= dataset[:,3].reshape((dataset.shape[0], 1))
    in_seq5= dataset[:,4].reshape((dataset.shape[0], 1))
    in_seq6= dataset[:,5].reshape((dataset.shape[0], 1))
    in_seq7= dataset[:,6].reshape((dataset.shape[0], 1))
    
    dataset = np.hstack((in_seq1, in_seq2, in_seq3, in_seq4,in_seq5,in_seq6,in_seq7))
    X, y = split_sequences(dataset, n_steps)
    n_features = X.shape[2]
    model = Sequential()
    model.add(LSTM(300, activation='relu', return_sequences=True, input_shape=(n_steps, n_features)))
    model.add(LSTM(300, activation='relu'))

    # 和多对一不同点在于，这里多对多的Dense的神经元=features数目
    model.add(Dense(n_features))
    model.compile(optimizer='adam', loss='mse')
    model.fit(X, y, epochs=100, verbose=2,shuffle=False)
    model.save('lstm_model.h5')
    last_input=np.array(dataset[-1:,:])
    return X,y,last_input,n_features,n_steps



# 将整型变为float
dataset = dataset.astype('float32')
#对数据集合进行标准化
scaler = MinMaxScaler(feature_range=(0, 1))

dataset=scaler.fit_transform(dataset)
#输入为标准化后的dataset 	#输出：X为lstm的输入，y为lstm的输出，x_input_last为最后一行dataset的数据，用于预测未来的输入,n_features是特征维度，n_steps是切片分层
X,y,last_input,n_features,n_steps=fitlstmmodel(dataset,n_steps=1)
#输入1为lstm的输入X，输入2为lstm的输出y，用于训练模型,输入3为标准化模型
#输出：testPredict为预测close的训练数据，testY为close的真实数据
#该函数目标输出训练的RMSE以及预测与训练数据的对比




###预测与评分
def Predict_RMSE_BA(X,y,scaler):
    model=load_model('lstm_model.h5') 
    trainPredict = model.predict(X)
    testPredict = scaler.inverse_transform(trainPredict)
    testY = scaler.inverse_transform(y)
    score(testY[:,0], testPredict[:,0])
    
    #'SOC土壤有机碳', 'SIC土壤无机碳', 'STC土壤全碳', '全氮N', '土壤C/N比'
    plt.plot(testY[:,0],color='blue', label='observed data')
    plt.plot(testPredict[:,0], color='red', label='LSTM')
    plt.xlabel( '年份')
    #'SOC土壤有机碳', 'SIC土壤无机碳', 'STC土壤全碳', '全氮N', '土壤C/N比'
    plt.ylabel( 'SOC土壤有机碳')
    plt.title( '2012~2020 %s SOC土壤有机碳 情况'%ppp)

    plt.legend() # 显示图例

    plt.savefig('./Q3 fig/2012~2020 %s  SOC土壤有机碳 情况.jpg'%ppp)
    plt.show()
    score(testY[:,1], testPredict[:,1])
    plt.plot(testY[:,1],color='blue', label='observed data')
    plt.plot(testPredict[:,1], color='red', label='LSTM')
    plt.xlabel( '年份')
    #'SOC土壤有机碳', 'SIC土壤无机碳', 'STC土壤全碳', '全氮N', '土壤C/N比'
    plt.ylabel( 'SIC土壤无机碳')
    plt.title( '2012~2020 %s  SIC土壤无机碳 情况'%ppp)

    plt.legend() # 显示图例

    plt.savefig('./Q3 fig/2012~2020 %s  SIC土壤无机碳 情况.jpg'%ppp)
    plt.show()    
    score(testY[:,2], testPredict[:,2])
    plt.plot(testY[:,2],color='blue', label='observed data')
    plt.plot(testPredict[:,2], color='red', label='LSTM')
    plt.xlabel( '年份')
    #'SOC土壤有机碳', 'SIC土壤无机碳', 'STC土壤全碳', '全氮N', '土壤C/N比'
    plt.ylabel( 'STC土壤全碳')
    plt.title( '2012~2020 %s  STC土壤全碳 情况'%ppp)

    plt.legend() # 显示图例

    plt.savefig('./Q3 fig/2012~2020 %s  STC土壤全碳 情况.jpg'%ppp)
    plt.show()   

    score(testY[:,3], testPredict[:,3])
    plt.plot(testY[:,3],color='blue', label='observed data')
    plt.plot(testPredict[:,3], color='red', label='LSTM')
    plt.xlabel( '年份')
    #'SOC土壤有机碳', 'SIC土壤无机碳', 'STC土壤全碳', '全氮N', '土壤C/N比'
    plt.ylabel( '全氮N')
    plt.title( '2012~2020 %s  全氮N 情况'%ppp)

    plt.legend() # 显示图例

    plt.savefig('./Q3 fig/2012~2020 %s  全氮N 情况.jpg'%ppp)
    plt.show()
    score(testY[:,4], testPredict[:,4])
    plt.plot(testY[:,4],color='blue', label='observed data')
    plt.plot(testPredict[:,4], color='red', label='LSTM')
    plt.xlabel( '年份')
    #'SOC土壤有机碳', 'SIC土壤无机碳', 'STC土壤全碳', '全氮N', '土壤C/N比'
    plt.ylabel( '土壤C/N比')
    plt.title( '2012~2020 %s  土壤C/N比 情况'%ppp)

    plt.legend() # 显示图例

    plt.savefig('./Q3 fig/2012~2020 %s 土壤CN比 情况.jpg'%ppp)
    plt.show()
    
    
    return testPredict,testY
def score(y_true, y_pre):
    # MSE
    print("MAPE :")
    print(mean_absolute_percentage_error(y_true, y_pre)) 
    # RMSE
    print("RMSE :")
    print(np.sqrt(metrics.mean_squared_error(y_true, y_pre))) 
    # MAE
    print("MAE :")
    print(metrics.mean_absolute_error(y_true, y_pre)) 
    # # R2
    # print("R2 :")
    # print(np.abs(r2_score(y_true,y_pre)))
testPredict,testY=Predict_RMSE_BA(X,y,scaler)


def Predict_future_plot(predict_forword_number,x_input,n_features,n_steps,scaler,testPredict,testY):
    model=load_model('lstm_model.h5') 
    predict_list=[]
    predict_list.append(x_input)
    while len(predict_list) < predict_forword_number:

        x_input = predict_list[-1].reshape((-1, n_steps, n_features))
        yhat = model.predict(x_input, verbose=0)
         #预测新值
        predict_list.append(yhat)
    #取出    
    
    Predict_forword = scaler.inverse_transform(np.array([ i.reshape(-1,1)[:,0].tolist() for i in predict_list]))
    return Predict_forword[1:,:].tolist()

y_pre=Predict_future_plot(2,last_input,n_features,n_steps,scaler,testPredict,testY)
y_pre
# Out:
# Epoch 1/100
# 1/1 - 5s - loss: 0.2966 - 5s/epoch - 5s/step
# Epoch 2/100
# 1/1 - 0s - loss: 0.2933 - 40ms/epoch - 40ms/step
# Epoch 3/100
# 1/1 - 0s - loss: 0.2901 - 15ms/epoch - 15ms/step
# Epoch 4/100
# 1/1 - 0s - loss: 0.2869 - 15ms/epoch - 15ms/step
# Epoch 5/100
# 1/1 - 0s - loss: 0.2835 - 17ms/epoch - 17ms/step
# Epoch 6/100
# 1/1 - 0s - loss: 0.2799 - 16ms/epoch - 16ms/step
# Epoch 7/100
# 1/1 - 0s - loss: 0.2760 - 47ms/epoch - 47ms/step
# Epoch 8/100
# 1/1 - 0s - loss: 0.2718 - 16ms/epoch - 16ms/step
# Epoch 9/100
# 1/1 - 0s - loss: 0.2672 - 19ms/epoch - 19ms/step
# Epoch 10/100
# 1/1 - 0s - loss: 0.2623 - 76ms/epoch - 76ms/step
# Epoch 11/100
# 1/1 - 0s - loss: 0.2568 - 76ms/epoch - 76ms/step
# Epoch 12/100
# 1/1 - 0s - loss: 0.2509 - 25ms/epoch - 25ms/step
# Epoch 13/100
# 1/1 - 0s - loss: 0.2445 - 20ms/epoch - 20ms/step
# Epoch 14/100
# 1/1 - 0s - loss: 0.2375 - 18ms/epoch - 18ms/step
# Epoch 15/100
# 1/1 - 0s - loss: 0.2300 - 20ms/epoch - 20ms/step
# Epoch 16/100
# 1/1 - 0s - loss: 0.2220 - 19ms/epoch - 19ms/step
# Epoch 17/100
# 1/1 - 0s - loss: 0.2134 - 15ms/epoch - 15ms/step
# Epoch 18/100
# 1/1 - 0s - loss: 0.2043 - 15ms/epoch - 15ms/step
# Epoch 19/100
# 1/1 - 0s - loss: 0.1947 - 18ms/epoch - 18ms/step
# Epoch 20/100
# 1/1 - 0s - loss: 0.1847 - 22ms/epoch - 22ms/step
# Epoch 21/100
# 1/1 - 0s - loss: 0.1746 - 50ms/epoch - 50ms/step
# Epoch 22/100
# 1/1 - 0s - loss: 0.1643 - 145ms/epoch - 145ms/step
# Epoch 23/100
# 1/1 - 0s - loss: 0.1543 - 80ms/epoch - 80ms/step
# Epoch 24/100
# 1/1 - 0s - loss: 0.1448 - 22ms/epoch - 22ms/step
# Epoch 25/100
# 1/1 - 0s - loss: 0.1363 - 65ms/epoch - 65ms/step
# Epoch 26/100
# 1/1 - 0s - loss: 0.1291 - 55ms/epoch - 55ms/step
# Epoch 27/100
# 1/1 - 0s - loss: 0.1237 - 14ms/epoch - 14ms/step
# Epoch 28/100
# 1/1 - 0s - loss: 0.1202 - 18ms/epoch - 18ms/step
# Epoch 29/100
# 1/1 - 0s - loss: 0.1184 - 17ms/epoch - 17ms/step
# Epoch 30/100
# 1/1 - 0s - loss: 0.1178 - 16ms/epoch - 16ms/step
# Epoch 31/100
# 1/1 - 0s - loss: 0.1177 - 19ms/epoch - 19ms/step
# Epoch 32/100
# 1/1 - 0s - loss: 0.1173 - 15ms/epoch - 15ms/step
# Epoch 33/100
# 1/1 - 0s - loss: 0.1161 - 16ms/epoch - 16ms/step
# Epoch 34/100
# 1/1 - 0s - loss: 0.1137 - 18ms/epoch - 18ms/step
# Epoch 35/100
# 1/1 - 0s - loss: 0.1103 - 15ms/epoch - 15ms/step
# Epoch 36/100
# 1/1 - 0s - loss: 0.1063 - 48ms/epoch - 48ms/step
# Epoch 37/100
# 1/1 - 0s - loss: 0.1021 - 47ms/epoch - 47ms/step
# Epoch 38/100
# 1/1 - 0s - loss: 0.0981 - 53ms/epoch - 53ms/step
# Epoch 39/100
# 1/1 - 0s - loss: 0.0943 - 26ms/epoch - 26ms/step
# Epoch 40/100
# 1/1 - 0s - loss: 0.0911 - 22ms/epoch - 22ms/step
# Epoch 41/100
# 1/1 - 0s - loss: 0.0884 - 21ms/epoch - 21ms/step
# Epoch 42/100
# 1/1 - 0s - loss: 0.0861 - 15ms/epoch - 15ms/step
# Epoch 43/100
# 1/1 - 0s - loss: 0.0840 - 16ms/epoch - 16ms/step
# Epoch 44/100
# 1/1 - 0s - loss: 0.0822 - 15ms/epoch - 15ms/step
# Epoch 45/100
# 1/1 - 0s - loss: 0.0804 - 16ms/epoch - 16ms/step
# Epoch 46/100
# 1/1 - 0s - loss: 0.0786 - 17ms/epoch - 17ms/step
# Epoch 47/100
# 1/1 - 0s - loss: 0.0768 - 14ms/epoch - 14ms/step
# Epoch 48/100
# 1/1 - 0s - loss: 0.0749 - 16ms/epoch - 16ms/step
# Epoch 49/100
# 1/1 - 0s - loss: 0.0730 - 46ms/epoch - 46ms/step
# Epoch 50/100
# 1/1 - 0s - loss: 0.0710 - 19ms/epoch - 19ms/step
# Epoch 51/100
# 1/1 - 0s - loss: 0.0691 - 22ms/epoch - 22ms/step
# Epoch 52/100
# 1/1 - 0s - loss: 0.0671 - 22ms/epoch - 22ms/step
# Epoch 53/100
# 1/1 - 0s - loss: 0.0653 - 49ms/epoch - 49ms/step
# Epoch 54/100
# 1/1 - 0s - loss: 0.0636 - 27ms/epoch - 27ms/step
# Epoch 55/100
# 1/1 - 0s - loss: 0.0620 - 53ms/epoch - 53ms/step
# Epoch 56/100
# 1/1 - 0s - loss: 0.0606 - 18ms/epoch - 18ms/step
# Epoch 57/100
# 1/1 - 0s - loss: 0.0593 - 15ms/epoch - 15ms/step
# Epoch 58/100
# 1/1 - 0s - loss: 0.0581 - 17ms/epoch - 17ms/step
# Epoch 59/100
# 1/1 - 0s - loss: 0.0569 - 19ms/epoch - 19ms/step
# Epoch 60/100
# 1/1 - 0s - loss: 0.0558 - 27ms/epoch - 27ms/step
# Epoch 61/100
# 1/1 - 0s - loss: 0.0546 - 31ms/epoch - 31ms/step
# Epoch 62/100
# 1/1 - 0s - loss: 0.0535 - 47ms/epoch - 47ms/step
# Epoch 63/100
# 1/1 - 0s - loss: 0.0523 - 32ms/epoch - 32ms/step
# Epoch 64/100
# 1/1 - 0s - loss: 0.0510 - 31ms/epoch - 31ms/step
# Epoch 65/100
# 1/1 - 0s - loss: 0.0498 - 46ms/epoch - 46ms/step
# Epoch 66/100
# 1/1 - 0s - loss: 0.0485 - 24ms/epoch - 24ms/step
# Epoch 67/100
# 1/1 - 0s - loss: 0.0473 - 17ms/epoch - 17ms/step
# Epoch 68/100
# 1/1 - 0s - loss: 0.0462 - 50ms/epoch - 50ms/step
# Epoch 69/100
# 1/1 - 0s - loss: 0.0450 - 16ms/epoch - 16ms/step
# Epoch 70/100
# 1/1 - 0s - loss: 0.0438 - 18ms/epoch - 18ms/step
# Epoch 71/100
# 1/1 - 0s - loss: 0.0426 - 15ms/epoch - 15ms/step
# Epoch 72/100
# 1/1 - 0s - loss: 0.0415 - 19ms/epoch - 19ms/step
# Epoch 73/100
# 1/1 - 0s - loss: 0.0403 - 15ms/epoch - 15ms/step
# Epoch 74/100
# 1/1 - 0s - loss: 0.0391 - 20ms/epoch - 20ms/step
# Epoch 75/100
# 1/1 - 0s - loss: 0.0379 - 51ms/epoch - 51ms/step
# Epoch 76/100
# 1/1 - 0s - loss: 0.0367 - 16ms/epoch - 16ms/step
# Epoch 77/100
# 1/1 - 0s - loss: 0.0356 - 23ms/epoch - 23ms/step
# Epoch 78/100
# 1/1 - 0s - loss: 0.0345 - 37ms/epoch - 37ms/step
# Epoch 79/100
# 1/1 - 0s - loss: 0.0335 - 30ms/epoch - 30ms/step
# Epoch 80/100
# 1/1 - 0s - loss: 0.0324 - 48ms/epoch - 48ms/step
# Epoch 81/100
# 1/1 - 0s - loss: 0.0315 - 14ms/epoch - 14ms/step
# Epoch 82/100
# 1/1 - 0s - loss: 0.0305 - 15ms/epoch - 15ms/step
# Epoch 83/100
# 1/1 - 0s - loss: 0.0297 - 20ms/epoch - 20ms/step
# Epoch 84/100
# 1/1 - 0s - loss: 0.0288 - 16ms/epoch - 16ms/step
# Epoch 85/100
# 1/1 - 0s - loss: 0.0280 - 16ms/epoch - 16ms/step
# Epoch 86/100
# 1/1 - 0s - loss: 0.0272 - 16ms/epoch - 16ms/step
# Epoch 87/100
# 1/1 - 0s - loss: 0.0264 - 48ms/epoch - 48ms/step
# Epoch 88/100
# 1/1 - 0s - loss: 0.0257 - 14ms/epoch - 14ms/step
# Epoch 89/100
# 1/1 - 0s - loss: 0.0250 - 57ms/epoch - 57ms/step
# Epoch 90/100
# 1/1 - 0s - loss: 0.0242 - 31ms/epoch - 31ms/step
# Epoch 91/100
# 1/1 - 0s - loss: 0.0235 - 16ms/epoch - 16ms/step
# Epoch 92/100
# 1/1 - 0s - loss: 0.0228 - 18ms/epoch - 18ms/step
# Epoch 93/100
# 1/1 - 0s - loss: 0.0221 - 20ms/epoch - 20ms/step
# Epoch 94/100
# 1/1 - 0s - loss: 0.0214 - 19ms/epoch - 19ms/step
# Epoch 95/100
# 1/1 - 0s - loss: 0.0206 - 19ms/epoch - 19ms/step
# Epoch 96/100
# 1/1 - 0s - loss: 0.0199 - 17ms/epoch - 17ms/step
# Epoch 97/100
# 1/1 - 0s - loss: 0.0192 - 19ms/epoch - 19ms/step
# Epoch 98/100
# 1/1 - 0s - loss: 0.0185 - 17ms/epoch - 17ms/step
# Epoch 99/100
# 1/1 - 0s - loss: 0.0178 - 16ms/epoch - 16ms/step
# Epoch 100/100
# 1/1 - 0s - loss: 0.0170 - 15ms/epoch - 15ms/step
# 1/1 [==============================] - 1s 641ms/step
# MAPE :
# 2.687077969312668
# RMSE :
# 0.5522503
# MAE :
# 0.4415052
# MAPE :
# 4.350682720541954
# RMSE :
# 0.30873483
# MAE :
# 0.27316713
# MAPE :
# 1.7925132066011429
# RMSE :
# 0.5007578
# MAE :
# 0.39508915
# MAPE :
# 4.2661696672439575
# RMSE :
# 0.08746197
# MAE :
# 0.08173579
# MAPE :
# 3.279685229063034
# RMSE :
# 0.5340705
# MAE :
# 0.40280104
# [[15.639857983742877,
#   5.6164590833470935,
#   21.516821373343472,
#   1.9185738812150595,
#   11.37154792681855,
#   9.2772921405009,
#   9.812312416471528]]

# %%
def po(plot,intensity):
    print('---------------分割线-------------------')
    print(plot+' '+intensity)
    print('-------------------------------')
    ppp=plot+' '+intensity
    temp=DF[(DF['放牧小区（plot）']==plot)&(DF['放牧强度（intensity）']==intensity)]
    temp.reset_index(inplace=True,drop=True)

    temp=temp.groupby('年份').mean()
    temp.reset_index(inplace=True,drop=False)


    for i in [ 'SOC土壤有机碳', 'SIC土壤无机碳', 'STC土壤全碳', '全氮N', '土壤C/N比']:
        plt.plot(temp['年份'].values,temp[i].values,label=i)

    plt.legend()
    plt.xlabel( '年份')
    plt.ylabel( '变量')
    plt.title( '2012~2020 %s 土壤化学性质 情况'%ppp)
    plt.savefig('./Q3 fig/2012~2022  %s土壤化学性质 情况.jpg'%ppp)

    dataset=temp[[ 'SOC土壤有机碳', 'SIC土壤无机碳', 'STC土壤全碳', '全氮N', '土壤C/N比','土壤蒸发量(W/m2)','土壤蒸发量(mm)']]

    #########LSTM多变量模型#############
    def split_sequences(sequences, n_steps):
        X, y = list(), list()
        for i in range(len(sequences)):
            end_ix = i + n_steps
            if end_ix > len(sequences)-1:
                break
            # 最关键的不一样在这一步
            seq_x, seq_y = sequences[i:end_ix, :], sequences[end_ix, :]
            X.append(seq_x)
            y.append(seq_y)
        return np.array(X), np.array(y)
    def mean_absolute_percentage_error(y_true, y_pred): 

        return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

    def fitlstmmodel(dataset,n_steps=1):
        #dataset：数据标准化后的dataset
        # n_steps：分片大小，默认为1
        #依次为：'PM2.5','AQI',  'PM10', 'SO2', 'CO', 'NO2', 'O3_8h', '最高气温', '最低气温'

        in_seq1= dataset[:,0].reshape((dataset.shape[0], 1))
        in_seq2= dataset[:,1].reshape((dataset.shape[0], 1))
        in_seq3= dataset[:,2].reshape((dataset.shape[0], 1))
        in_seq4= dataset[:,3].reshape((dataset.shape[0], 1))
        in_seq5= dataset[:,4].reshape((dataset.shape[0], 1))
        in_seq6= dataset[:,5].reshape((dataset.shape[0], 1))
        in_seq7= dataset[:,6].reshape((dataset.shape[0], 1))

        dataset = np.hstack((in_seq1, in_seq2, in_seq3, in_seq4,in_seq5,in_seq6,in_seq7))
        X, y = split_sequences(dataset, n_steps)
        n_features = X.shape[2]
        model = Sequential()
        model.add(LSTM(300, activation='relu', return_sequences=True, input_shape=(n_steps, n_features)))
        model.add(LSTM(300, activation='relu'))

        # 和多对一不同点在于，这里多对多的Dense的神经元=features数目
        model.add(Dense(n_features))
        model.compile(optimizer='adam', loss='mse')
        model.fit(X, y, epochs=100, verbose=2,shuffle=False)
        model.save('lstm_model.h5')
        last_input=np.array(dataset[-1:,:])
        return X,y,last_input,n_features,n_steps



    # 将整型变为float
    dataset = dataset.astype('float32')
    #对数据集合进行标准化
    scaler = MinMaxScaler(feature_range=(0, 1))

    dataset=scaler.fit_transform(dataset)
    #输入为标准化后的dataset 	#输出：X为lstm的输入，y为lstm的输出，x_input_last为最后一行dataset的数据，用于预测未来的输入,n_features是特征维度，n_steps是切片分层
    X,y,last_input,n_features,n_steps=fitlstmmodel(dataset,n_steps=1)
    #输入1为lstm的输入X，输入2为lstm的输出y，用于训练模型,输入3为标准化模型
    #输出：testPredict为预测close的训练数据，testY为close的真实数据
    #该函数目标输出训练的RMSE以及预测与训练数据的对比




    ###预测与评分
    def Predict_RMSE_BA(X,y,scaler):
        model=load_model('lstm_model.h5') 
        trainPredict = model.predict(X)
        testPredict = scaler.inverse_transform(trainPredict)
        testY = scaler.inverse_transform(y)
        score(testY[:,0], testPredict[:,0])

        #'SOC土壤有机碳', 'SIC土壤无机碳', 'STC土壤全碳', '全氮N', '土壤C/N比'
        plt.plot(testY[:,0],color='blue', label='observed data')
        plt.plot(testPredict[:,0], color='red', label='LSTM')
        plt.xlabel( '年份')
        #'SOC土壤有机碳', 'SIC土壤无机碳', 'STC土壤全碳', '全氮N', '土壤C/N比'
        plt.ylabel( 'SOC土壤有机碳')
        plt.title( '2012~2020 %s SOC土壤有机碳 情况'%ppp)

        plt.legend() # 显示图例

        plt.savefig('./Q3 fig/2012~2020 %s  SOC土壤有机碳 情况.jpg'%ppp)
        plt.show()
        score(testY[:,1], testPredict[:,1])
        plt.plot(testY[:,1],color='blue', label='observed data')
        plt.plot(testPredict[:,1], color='red', label='LSTM')
        plt.xlabel( '年份')
        #'SOC土壤有机碳', 'SIC土壤无机碳', 'STC土壤全碳', '全氮N', '土壤C/N比'
        plt.ylabel( 'SIC土壤无机碳')
        plt.title( '2012~2020 %s  SIC土壤无机碳 情况'%ppp)

        plt.legend() # 显示图例

        plt.savefig('./Q3 fig/2012~2020 %s  SIC土壤无机碳 情况.jpg'%ppp)
        plt.show()
        score(testY[:,2], testPredict[:,2])
        plt.plot(testY[:,2],color='blue', label='observed data')
        plt.plot(testPredict[:,2], color='red', label='LSTM')
        plt.xlabel( '年份')
        #'SOC土壤有机碳', 'SIC土壤无机碳', 'STC土壤全碳', '全氮N', '土壤C/N比'
        plt.ylabel( 'STC土壤全碳')
        plt.title( '2012~2020 %s  STC土壤全碳 情况'%ppp)

        plt.legend() # 显示图例

        plt.savefig('./Q3 fig/2012~2020 %s  STC土壤全碳 情况.jpg'%ppp)
        plt.show()

        score(testY[:,3], testPredict[:,3])
        plt.plot(testY[:,3],color='blue', label='observed data')
        plt.plot(testPredict[:,3], color='red', label='LSTM')
        plt.xlabel( '年份')
        #'SOC土壤有机碳', 'SIC土壤无机碳', 'STC土壤全碳', '全氮N', '土壤C/N比'
        plt.ylabel( '全氮N')
        plt.title( '2012~2020 %s  全氮N 情况'%ppp)

        plt.legend() # 显示图例

        plt.savefig('./Q3 fig/2012~2020 %s  全氮N 情况.jpg'%ppp)
        plt.show()
        score(testY[:,4], testPredict[:,4])
        plt.plot(testY[:,4],color='blue', label='observed data')
        plt.plot(testPredict[:,4], color='red', label='LSTM')
        plt.xlabel( '年份')
        #'SOC土壤有机碳', 'SIC土壤无机碳', 'STC土壤全碳', '全氮N', '土壤C/N比'
        plt.ylabel( '土壤C/N比')
        plt.title( '2012~2020 %s  土壤C/N比 情况'%ppp)

        plt.legend() # 显示图例

        plt.savefig('./Q3 fig/2012~2020  %s 土壤CN比 情况.jpg'%ppp)
        plt.show()


        return testPredict,testY
    def score(y_true, y_pre):
        # MSE
        print("MAPE :")
        print(mean_absolute_percentage_error(y_true, y_pre)) 
        # RMSE
        print("RMSE :")
        print(np.sqrt(metrics.mean_squared_error(y_true, y_pre))) 
        # MAE
        print("MAE :")
        print(metrics.mean_absolute_error(y_true, y_pre)) 
        # # R2
        # print("R2 :")
        # print(np.abs(r2_score(y_true,y_pre)))
    testPredict,testY=Predict_RMSE_BA(X,y,scaler)


    def Predict_future_plot(predict_forword_number,x_input,n_features,n_steps,scaler,testPredict,testY):
        model=load_model('lstm_model.h5') 
        predict_list=[]
        predict_list.append(x_input)
        while len(predict_list) < predict_forword_number:

            x_input = predict_list[-1].reshape((-1, n_steps, n_features))
            yhat = model.predict(x_input, verbose=0)
             #预测新值
            predict_list.append(yhat)
        #取出    

        Predict_forword = scaler.inverse_transform(np.array([ i.reshape(-1,1)[:,0].tolist() for i in predict_list]))
        return Predict_forword[1:,:].tolist()

    y_pre=Predict_future_plot(2,last_input,n_features,n_steps,scaler,testPredict,testY)
    print(y_pre)

# %%
plot='G21'
intensity='NG'
po(plot,intensity)
# Out:
# ---------------分割线-------------------
# G21 NG
# -------------------------------
# Epoch 1/100
# 1/1 - 5s - loss: 0.3774 - 5s/epoch - 5s/step
# Epoch 2/100
# 1/1 - 0s - loss: 0.3733 - 16ms/epoch - 16ms/step
# Epoch 3/100
# 1/1 - 0s - loss: 0.3693 - 16ms/epoch - 16ms/step
# Epoch 4/100
# 1/1 - 0s - loss: 0.3654 - 18ms/epoch - 18ms/step
# Epoch 5/100
# 1/1 - 0s - loss: 0.3612 - 15ms/epoch - 15ms/step
# Epoch 6/100
# 1/1 - 0s - loss: 0.3566 - 16ms/epoch - 16ms/step
# Epoch 7/100
# 1/1 - 0s - loss: 0.3518 - 19ms/epoch - 19ms/step
# Epoch 8/100
# 1/1 - 0s - loss: 0.3464 - 15ms/epoch - 15ms/step
# Epoch 9/100
# 1/1 - 0s - loss: 0.3406 - 16ms/epoch - 16ms/step
# Epoch 10/100
# 1/1 - 0s - loss: 0.3342 - 19ms/epoch - 19ms/step
# Epoch 11/100
# 1/1 - 0s - loss: 0.3273 - 15ms/epoch - 15ms/step
# Epoch 12/100
# 1/1 - 0s - loss: 0.3197 - 17ms/epoch - 17ms/step
# Epoch 13/100
# 1/1 - 0s - loss: 0.3114 - 19ms/epoch - 19ms/step
# Epoch 14/100
# 1/1 - 0s - loss: 0.3024 - 20ms/epoch - 20ms/step
# Epoch 15/100
# 1/1 - 0s - loss: 0.2928 - 21ms/epoch - 21ms/step
# Epoch 16/100
# 1/1 - 0s - loss: 0.2824 - 16ms/epoch - 16ms/step
# Epoch 17/100
# 1/1 - 0s - loss: 0.2712 - 16ms/epoch - 16ms/step
# Epoch 18/100
# 1/1 - 0s - loss: 0.2594 - 16ms/epoch - 16ms/step
# Epoch 19/100
# 1/1 - 0s - loss: 0.2470 - 37ms/epoch - 37ms/step
# Epoch 20/100
# 1/1 - 0s - loss: 0.2340 - 21ms/epoch - 21ms/step
# Epoch 21/100
# 1/1 - 0s - loss: 0.2207 - 23ms/epoch - 23ms/step
# Epoch 22/100
# 1/1 - 0s - loss: 0.2071 - 19ms/epoch - 19ms/step
# Epoch 23/100
# 1/1 - 0s - loss: 0.1938 - 15ms/epoch - 15ms/step
# Epoch 24/100
# 1/1 - 0s - loss: 0.1809 - 18ms/epoch - 18ms/step
# Epoch 25/100
# 1/1 - 0s - loss: 0.1691 - 20ms/epoch - 20ms/step
# Epoch 26/100
# 1/1 - 0s - loss: 0.1587 - 20ms/epoch - 20ms/step
# Epoch 27/100
# 1/1 - 0s - loss: 0.1506 - 29ms/epoch - 29ms/step
# Epoch 28/100
# 1/1 - 0s - loss: 0.1450 - 69ms/epoch - 69ms/step
# Epoch 29/100
# 1/1 - 0s - loss: 0.1422 - 15ms/epoch - 15ms/step
# Epoch 30/100
# 1/1 - 0s - loss: 0.1418 - 16ms/epoch - 16ms/step
# Epoch 31/100
# 1/1 - 0s - loss: 0.1428 - 17ms/epoch - 17ms/step
# Epoch 32/100
# 1/1 - 0s - loss: 0.1440 - 18ms/epoch - 18ms/step
# Epoch 33/100
# 1/1 - 0s - loss: 0.1442 - 18ms/epoch - 18ms/step
# Epoch 34/100
# 1/1 - 0s - loss: 0.1428 - 19ms/epoch - 19ms/step
# Epoch 35/100
# 1/1 - 0s - loss: 0.1398 - 21ms/epoch - 21ms/step
# Epoch 36/100
# 1/1 - 0s - loss: 0.1355 - 19ms/epoch - 19ms/step
# Epoch 37/100
# 1/1 - 0s - loss: 0.1305 - 18ms/epoch - 18ms/step
# Epoch 38/100
# 1/1 - 0s - loss: 0.1255 - 22ms/epoch - 22ms/step
# Epoch 39/100
# 1/1 - 0s - loss: 0.1208 - 22ms/epoch - 22ms/step
# Epoch 40/100
# 1/1 - 0s - loss: 0.1167 - 26ms/epoch - 26ms/step
# Epoch 41/100
# 1/1 - 0s - loss: 0.1134 - 20ms/epoch - 20ms/step
# Epoch 42/100
# 1/1 - 0s - loss: 0.1107 - 18ms/epoch - 18ms/step
# Epoch 43/100
# 1/1 - 0s - loss: 0.1085 - 17ms/epoch - 17ms/step
# Epoch 44/100
# 1/1 - 0s - loss: 0.1067 - 17ms/epoch - 17ms/step
# Epoch 45/100
# 1/1 - 0s - loss: 0.1051 - 19ms/epoch - 19ms/step
# Epoch 46/100
# 1/1 - 0s - loss: 0.1035 - 16ms/epoch - 16ms/step
# Epoch 47/100
# 1/1 - 0s - loss: 0.1019 - 18ms/epoch - 18ms/step
# Epoch 48/100
# 1/1 - 0s - loss: 0.1001 - 15ms/epoch - 15ms/step
# Epoch 49/100
# 1/1 - 0s - loss: 0.0982 - 16ms/epoch - 16ms/step
# Epoch 50/100
# 1/1 - 0s - loss: 0.0962 - 17ms/epoch - 17ms/step
# Epoch 51/100
# 1/1 - 0s - loss: 0.0940 - 15ms/epoch - 15ms/step
# Epoch 52/100
# 1/1 - 0s - loss: 0.0919 - 15ms/epoch - 15ms/step
# Epoch 53/100
# 1/1 - 0s - loss: 0.0898 - 18ms/epoch - 18ms/step
# Epoch 54/100
# 1/1 - 0s - loss: 0.0878 - 15ms/epoch - 15ms/step
# Epoch 55/100
# 1/1 - 0s - loss: 0.0860 - 17ms/epoch - 17ms/step
# Epoch 56/100
# 1/1 - 0s - loss: 0.0843 - 17ms/epoch - 17ms/step
# Epoch 57/100
# 1/1 - 0s - loss: 0.0827 - 16ms/epoch - 16ms/step
# Epoch 58/100
# 1/1 - 0s - loss: 0.0813 - 15ms/epoch - 15ms/step
# Epoch 59/100
# 1/1 - 0s - loss: 0.0800 - 18ms/epoch - 18ms/step
# Epoch 60/100
# 1/1 - 0s - loss: 0.0787 - 14ms/epoch - 14ms/step
# Epoch 61/100
# 1/1 - 0s - loss: 0.0775 - 16ms/epoch - 16ms/step
# Epoch 62/100
# 1/1 - 0s - loss: 0.0761 - 16ms/epoch - 16ms/step
# Epoch 63/100
# 1/1 - 0s - loss: 0.0747 - 16ms/epoch - 16ms/step
# Epoch 64/100
# 1/1 - 0s - loss: 0.0732 - 18ms/epoch - 18ms/step
# Epoch 65/100
# 1/1 - 0s - loss: 0.0717 - 15ms/epoch - 15ms/step
# Epoch 66/100
# 1/1 - 0s - loss: 0.0701 - 16ms/epoch - 16ms/step
# Epoch 67/100
# 1/1 - 0s - loss: 0.0686 - 16ms/epoch - 16ms/step
# Epoch 68/100
# 1/1 - 0s - loss: 0.0671 - 16ms/epoch - 16ms/step
# Epoch 69/100
# 1/1 - 0s - loss: 0.0657 - 16ms/epoch - 16ms/step
# Epoch 70/100
# 1/1 - 0s - loss: 0.0643 - 17ms/epoch - 17ms/step
# Epoch 71/100
# 1/1 - 0s - loss: 0.0629 - 14ms/epoch - 14ms/step
# Epoch 72/100
# 1/1 - 0s - loss: 0.0616 - 15ms/epoch - 15ms/step
# Epoch 73/100
# 1/1 - 0s - loss: 0.0603 - 16ms/epoch - 16ms/step
# Epoch 74/100
# 1/1 - 0s - loss: 0.0590 - 19ms/epoch - 19ms/step
# Epoch 75/100
# 1/1 - 0s - loss: 0.0577 - 21ms/epoch - 21ms/step
# Epoch 76/100
# 1/1 - 0s - loss: 0.0565 - 16ms/epoch - 16ms/step
# Epoch 77/100
# 1/1 - 0s - loss: 0.0553 - 15ms/epoch - 15ms/step
# Epoch 78/100
# 1/1 - 0s - loss: 0.0541 - 19ms/epoch - 19ms/step
# Epoch 79/100
# 1/1 - 0s - loss: 0.0531 - 35ms/epoch - 35ms/step
# Epoch 80/100
# 1/1 - 0s - loss: 0.0521 - 15ms/epoch - 15ms/step
# Epoch 81/100
# 1/1 - 0s - loss: 0.0511 - 18ms/epoch - 18ms/step
# Epoch 82/100
# 1/1 - 0s - loss: 0.0503 - 16ms/epoch - 16ms/step
# Epoch 83/100
# 1/1 - 0s - loss: 0.0496 - 20ms/epoch - 20ms/step
# Epoch 84/100
# 1/1 - 0s - loss: 0.0489 - 15ms/epoch - 15ms/step
# Epoch 85/100
# 1/1 - 0s - loss: 0.0482 - 16ms/epoch - 16ms/step
# Epoch 86/100
# 1/1 - 0s - loss: 0.0477 - 17ms/epoch - 17ms/step
# Epoch 87/100
# 1/1 - 0s - loss: 0.0471 - 14ms/epoch - 14ms/step
# Epoch 88/100
# 1/1 - 0s - loss: 0.0466 - 17ms/epoch - 17ms/step
# Epoch 89/100
# 1/1 - 0s - loss: 0.0461 - 17ms/epoch - 17ms/step
# Epoch 90/100
# 1/1 - 0s - loss: 0.0456 - 16ms/epoch - 16ms/step
# Epoch 91/100
# 1/1 - 0s - loss: 0.0451 - 17ms/epoch - 17ms/step
# Epoch 92/100
# 1/1 - 0s - loss: 0.0446 - 17ms/epoch - 17ms/step
# Epoch 93/100
# 1/1 - 0s - loss: 0.0441 - 15ms/epoch - 15ms/step
# Epoch 94/100
# 1/1 - 0s - loss: 0.0436 - 16ms/epoch - 16ms/step
# Epoch 95/100
# 1/1 - 0s - loss: 0.0430 - 18ms/epoch - 18ms/step
# Epoch 96/100
# 1/1 - 0s - loss: 0.0424 - 16ms/epoch - 16ms/step
# Epoch 97/100
# 1/1 - 0s - loss: 0.0418 - 16ms/epoch - 16ms/step
# Epoch 98/100
# 1/1 - 0s - loss: 0.0412 - 14ms/epoch - 14ms/step
# Epoch 99/100
# 1/1 - 0s - loss: 0.0405 - 16ms/epoch - 16ms/step
# Epoch 100/100
# 1/1 - 0s - loss: 0.0398 - 19ms/epoch - 19ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001A813B1B288> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 620ms/step
# MAPE :
# 4.996957629919052
# RMSE :
# 0.8996434
# MAE :
# 0.82245946
# MAPE :
# 8.851718157529831
# RMSE :
# 0.64701277
# MAE :
# 0.5474263
# MAPE :
# 1.7090419307351112
# RMSE :
# 0.43232504
# MAE :
# 0.39362574
# MAPE :
# 4.18415367603302
# RMSE :
# 0.094841674
# MAE :
# 0.08457434
# MAPE :
# 1.9502641633152962
# RMSE :
# 0.2772216
# MAE :
# 0.22480488
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001A811996EE8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [[19.424617431351084, 4.019974669548419, 23.85965736747741, 2.3558923025183485, 10.046867789832564, 10.829172128208873, 11.441258277838982]]

# %% [markdown]
# ![image.png](attachment:4888987e-de4d-4039-a2ae-5f45b441e0d9.png)

# %%
intensity='LGI'
plot='G6'
po(plot,intensity)
plot='G12'
po(plot,intensity)
plot='G18'
po(plot,intensity)
# Out:
# ---------------分割线-------------------
# G6 LGI
# -------------------------------
# Epoch 1/100
# 1/1 - 5s - loss: 0.3485 - 5s/epoch - 5s/step
# Epoch 2/100
# 1/1 - 0s - loss: 0.3445 - 15ms/epoch - 15ms/step
# Epoch 3/100
# 1/1 - 0s - loss: 0.3407 - 17ms/epoch - 17ms/step
# Epoch 4/100
# 1/1 - 0s - loss: 0.3369 - 15ms/epoch - 15ms/step
# Epoch 5/100
# 1/1 - 0s - loss: 0.3330 - 16ms/epoch - 16ms/step
# Epoch 6/100
# 1/1 - 0s - loss: 0.
ms/step
# Epoch 100/100
# 1/1 - 0s - loss: 0.0255 - 14ms/epoch - 14ms/step
# 1/1 [==============================] - 1s 586ms/step
# MAPE :
# 0.521261990070343
# RMSE :
# 0.0994147
# MAE :
# 0.07670784
# MAPE :
# 5.6171610951423645
# RMSE :
# 0.3287515
# MAE :
# 0.28026003
# MAPE :
# 1.0949996300041676
# RMSE :
# 0.29506427
# MAE :
# 0.23356295
# MAPE :
# 3.5579215735197067
# RMSE :
# 0.0722774
# MAE :
# 0.065114826
# MAPE :
# 1.4176905155181885
# RMSE :
# 0.20707789
# MAE :
# 0.1810751
# [[14.579924046461098, 4.379159803375641, 18.71609917152716, 1.921641404356368, 9.95058528593701, 10.296454471129861, 10.823143254060865]]
# ---------------分割线-------------------
# G12 LGI
# -------------------------------
# Epoch 1/100
# 1/1 - 4s - loss: 0.3947 - 4s/epoch - 4s/step
# Epoch 2/100
# 1/1 - 0s - loss: 0.3902 - 15ms/epoch - 15ms/step
# Epoch 3/100
# 1/1 - 0s - loss: 0.3859 - 15ms/epoch - 15ms/step
# Epoch 4/100
# 1/1 - 0s - loss: 0.3817 - 21ms/epoch - 21ms/step
# Epoch 5/100
# 1/1 - 0s - loss: 0.3773 - 19ms/epoch - 19ms/step
# Epoch 6/100
# 1/1 - 0s - loss: 0.3726 - 36ms/epoch - 36ms/step
# Epoch 7/100
# 1/1 - 0s - loss: 0.3676 - 22ms/epoch - 22ms/step
# Epoch 8/100
# 1/1 - 0s - loss: 0.3621 - 18ms/epoch - 18ms/step
# Epoch 9/100
# 1/1 - 0s - loss: 0.3561 - 16ms/epoch - 16ms/step
# Epoch 10/100
# 1/1 - 0s - loss: 0.3496 - 19ms/epoch - 19ms/step
# Epoch 11/100
# 1/1 - 0s - loss: 0.3426 - 19ms/epoch - 19ms/step
# Epoch 12/100
# 1/1 - 0s - loss: 0.3348 - 20ms/epoch - 20ms/step
# Epoch 13/100
# 1/1 - 0s - loss: 0.3265 - 14ms/epoch - 14ms/step
# Epoch 14/100
# 1/1 - 0s - loss: 0.3174 - 16ms/epoch - 16ms/step
# Epoch 15/100
# 1/1 - 0s - loss: 0.3075 - 17ms/epoch - 17ms/step
# Epoch 16/100
# 1/1 - 0s - loss: 0.2969 - 17ms/epoch - 17ms/step
# Epoch 17/100
# 1/1 - 0s - loss: 0.2856 - 16ms/epoch - 16ms/step
# Epoch 18/100
# 1/1 - 0s - loss: 0.2735 - 17ms/epoch - 17ms/step
# Epoch 19/100
# 1/1 - 0s - loss: 0.2608 - 18ms/epoch - 18ms/step
# Epoch 20/100
# 1/1 - 0s - loss: 0.2476 - 15ms/epoch - 15ms/step
# Epoch 21/100
# 1/1 - 0s - loss: 0.2339 - 17ms/epoch - 17ms/step
# Epoch 22/100
# 1/1 - 0s - loss: 0.2201 - 17ms/epoch - 17ms/step
# Epoch 23/100
# 1/1 - 0s - loss: 0.2065 - 15ms/epoch - 15ms/step
# Epoch 24/100
# 1/1 - 0s - loss: 0.1935 - 17ms/epoch - 17ms/step
# Epoch 25/100
# 1/1 - 0s - loss: 0.1817 - 20ms/epoch - 20ms/step
# Epoch 26/100
# 1/1 - 0s - loss: 0.1717 - 20ms/epoch - 20ms/step
# Epoch 27/100
# 1/1 - 0s - loss: 0.1643 - 15ms/epoch - 15ms/step
# Epoch 28/100
# 1/1 - 0s - loss: 0.1601 - 16ms/epoch - 16ms/step
# Epoch 29/100
# 1/1 - 0s - loss: 0.1591 - 17ms/epoch - 17ms/step
# Epoch 30/100
# 1/1 - 0s - loss: 0.1607 - 14ms/epoch - 14ms/step
# Epoch 31/100
# 1/1 - 0s - loss: 0.1633 - 15ms/epoch - 15ms/step
# Epoch 32/100
# 1/1 - 0s - loss: 0.1651 - 17ms/epoch - 17ms/step
# Epoch 33/100
# 1/1 - 0s - loss: 0.1652 - 14ms/epoch - 14ms/step
# Epoch 34/100
# 1/1 - 0s - loss: 0.1631 - 16ms/epoch - 16ms/step
# Epoch 35/100
# 1/1 - 0s - loss: 0.1595 - 17ms/epoch - 17ms/step
# Epoch 36/100
# 1/1 - 0s - loss: 0.1549 - 15ms/epoch - 15ms/step
# Epoch 37/100
# 1/1 - 0s - loss: 0.1502 - 17ms/epoch - 17ms/step
# Epoch 38/100
# 1/1 - 0s - loss: 0.1460 - 18ms/epoch - 18ms/step
# Epoch 39/100
# 1/1 - 0s - loss: 0.1425 - 21ms/epoch - 21ms/step
# Epoch 40/100
# 1/1 - 0s - loss: 0.1399 - 16ms/epoch - 16ms/step
# Epoch 41/100
# 1/1 - 0s - loss: 0.1381 - 15ms/epoch - 15ms/step
# Epoch 42/100
# 1/1 - 0s - loss: 0.1369 - 16ms/epoch - 16ms/step
# Epoch 43/100
# 1/1 - 0s - loss: 0.1360 - 18ms/epoch - 18ms/step
# Epoch 44/100
# 1/1 - 0s - loss: 0.1354 - 31ms/epoch - 31ms/step
# Epoch 45/100
# 1/1 - 0s - loss: 0.1348 - 17ms/epoch - 17ms/step
# Epoch 46/100
# 1/1 - 0s - loss: 0.1341 - 15ms/epoch - 15ms/step
# Epoch 47/100
# 1/1 - 0s - loss: 0.1332 - 18ms/epoch - 18ms/step
# Epoch 48/100
# 1/1 - 0s - loss: 0.1321 - 18ms/epoch - 18ms/step
# Epoch 49/100
# 1/1 - 0s - loss: 0.1308 - 18ms/epoch - 18ms/step
# Epoch 50/100
# 1/1 - 0s - loss: 0.1293 - 15ms/epoch - 15ms/step
# Epoch 51/100
# 1/1 - 0s - loss: 0.1277 - 16ms/epoch - 16ms/step
# Epoch 52/100
# 1/1 - 0s - loss: 0.1261 - 20ms/epoch - 20ms/step
# Epoch 53/100
# 1/1 - 0s - loss: 0.1245 - 20ms/epoch - 20ms/step
# Epoch 54/100
# 1/1 - 0s - loss: 0.1230 - 31ms/epoch - 31ms/step
# Epoch 55/100
# 1/1 - 0s - loss: 0.1215 - 19ms/epoch - 19ms/step
# Epoch 56/100
# 1/1 - 0s - loss: 0.1202 - 18ms/epoch - 18ms/step
# Epoch 57/100
# 1/1 - 0s - loss: 0.1190 - 20ms/epoch - 20ms/step
# Epoch 58/100
# 1/1 - 0s - loss: 0.1179 - 15ms/epoch - 15ms/step
# Epoch 59/100
# 1/1 - 0s - loss: 0.1168 - 17ms/epoch - 17ms/step
# Epoch 60/100
# 1/1 - 0s - loss: 0.1157 - 17ms/epoch - 17ms/step
# Epoch 61/100
# 1/1 - 0s - loss: 0.1147 - 16ms/epoch - 16ms/step
# Epoch 62/100
# 1/1 - 0s - loss: 0.1135 - 16ms/epoch - 16ms/step
# Epoch 63/100
# 1/1 - 0s - loss: 0.1123 - 32ms/epoch - 32ms/step
# Epoch 64/100
# 1/1 - 0s - loss: 0.1110 - 18ms/epoch - 18ms/step
# Epoch 65/100
# 1/1 - 0s - loss: 0.1097 - 17ms/epoch - 17ms/step
# Epoch 66/100
# 1/1 - 0s - loss: 0.1084 - 16ms/epoch - 16ms/step
# Epoch 67/100
# 1/1 - 0s - loss: 0.1070 - 18ms/epoch - 18ms/step
# Epoch 68/100
# 1/1 - 0s - loss: 0.1057 - 16ms/epoch - 16ms/step
# Epoch 69/100
# 1/1 - 0s - loss: 0.1044 - 16ms/epoch - 16ms/step
# Epoch 70/100
# 1/1 - 0s - loss: 0.1032 - 18ms/epoch - 18ms/step
# Epoch 71/100
# 1/1 - 0s - loss: 0.1019 - 19ms/epoch - 19ms/step
# Epoch 72/100
# 1/1 - 0s - loss: 0.1007 - 26ms/epoch - 26ms/step
# Epoch 73/100
# 1/1 - 0s - loss: 0.0995 - 19ms/epoch - 19ms/step
# Epoch 74/100
# 1/1 - 0s - loss: 0.
ms/step
# Epoch 44/100
# 1/1 - 0s - loss: 0.1411 - 29ms/epoch - 29ms/step
# Epoch 45/100
# 1/1 - 0s - loss: 0.1396 - 33ms/epoch - 33ms/step
# Epoch 46/100
# 1/1 - 0s - loss: 0.1384 - 29ms/epoch - 29ms/step
# Epoch 47/100
# 1/1 - 0s - loss: 0.1373 - 29ms/epoch - 29ms/step
# Epoch 48/100
# 1/1 - 0s - loss: 0.1361 - 71ms/epoch - 71ms/step
# Epoch 49/100
# 1/1 - 0s - loss: 0.1348 - 27ms/epoch - 27ms/step
# Epoch 50/100
# 1/1 - 0s - loss: 0.1333 - 44ms/epoch - 44ms/step
# Epoch 51/100
# 1/1 - 0s - loss: 0.1316 - 55ms/epoch - 55ms/step
# Epoch 52/100
# 1/1 - 0s - loss: 0.1298 - 75ms/epoch - 75ms/step
# Epoch 53/100
# 1/1 - 0s - loss: 0.1280 - 103ms/epoch - 103ms/step
# Epoch 54/100
# 1/1 - 0s - loss: 0.1261 - 49ms/epoch - 49ms/step
# Epoch 55/100
# 1/1 - 0s - loss: 0.1243 - 30ms/epoch - 30ms/step
# Epoch 56/100
# 1/1 - 0s - loss: 0.1226 - 24ms/epoch - 24ms/step
# Epoch 57/100
# 1/1 - 0s - loss: 0.1210 - 47ms/epoch - 47ms/step
# Epoch 58/100
# 1/1 - 0s - loss: 0.1195 - 22ms/epoch - 22ms/step
# Epoch 59/100
# 1/1 - 0s - loss: 0.1182 - 51ms/epoch - 51ms/step
# Epoch 60/100
# 1/1 - 0s - loss: 0.1169 - 23ms/epoch - 23ms/step
# Epoch 61/100
# 1/1 - 0s - loss: 0.1156 - 52ms/epoch - 52ms/step
# Epoch 62/100
# 1/1 - 0s - loss: 0.1143 - 48ms/epoch - 48ms/step
# Epoch 63/100
# 1/1 - 0s - loss: 0.1130 - 19ms/epoch - 19ms/step
# Epoch 64/100
# 1/1 - 0s - loss: 0.1116 - 47ms/epoch - 47ms/step
# Epoch 65/100
# 1/1 - 0s - loss: 0.1102 - 50ms/epoch - 50ms/step
# Epoch 66/100
# 1/1 - 0s - loss: 0.1087 - 22ms/epoch - 22ms/step
# Epoch 67/100
# 1/1 - 0s - loss: 0.1071 - 27ms/epoch - 27ms/step
# Epoch 68/100
# 1/1 - 0s - loss: 0.1055 - 18ms/epoch - 18ms/step
# Epoch 69/100
# 1/1 - 0s - loss: 0.1040 - 48ms/epoch - 48ms/step
# Epoch 70/100
# 1/1 - 0s - loss: 0.1024 - 29ms/epoch - 29ms/step
# Epoch 71/100
# 1/1 - 0s - loss: 0.1009 - 50ms/epoch - 50ms/step
# Epoch 72/100
# 1/1 - 0s - loss: 0.0994 - 49ms/epoch - 49ms/step
# Epoch 73/100
# 1/1 - 0s - loss: 0.0978 - 21ms/epoch - 21ms/step
# Epoch 74/100
# 1/1 - 0s - loss: 0.0963 - 50ms/epoch - 50ms/step
# Epoch 75/100
# 1/1 - 0s - loss: 0.0948 - 17ms/epoch - 17ms/step
# Epoch 76/100
# 1/1 - 0s - loss: 0.0932 - 33ms/epoch - 33ms/step
# Epoch 77/100
# 1/1 - 0s - loss: 0.0916 - 47ms/epoch - 47ms/step
# Epoch 78/100
# 1/1 - 0s - loss: 0.0900 - 39ms/epoch - 39ms/step
# Epoch 79/100
# 1/1 - 0s - loss: 0.0884 - 56ms/epoch - 56ms/step
# Epoch 80/100
# 1/1 - 0s - loss: 0.0868 - 15ms/epoch - 15ms/step
# Epoch 81/100
# 1/1 - 0s - loss: 0.0852 - 27ms/epoch - 27ms/step
# Epoch 82/100
# 1/1 - 0s - loss: 0.0836 - 36ms/epoch - 36ms/step
# Epoch 83/100
# 1/1 - 0s - loss: 0.0820 - 29ms/epoch - 29ms/step
# Epoch 84/100
# 1/1 - 0s - loss: 0.0804 - 31ms/epoch - 31ms/step
# Epoch 85/100
# 1/1 - 0s - loss: 0.0789 - 41ms/epoch - 41ms/step
# Epoch 86/100
# 1/1 - 0s - loss: 0.0773 - 23ms/epoch - 23ms/step
# Epoch 87/100
# 1/1 - 0s - loss: 0.0757 - 20ms/epoch - 20ms/step
# Epoch 88/100
# 1/1 - 0s - loss: 0.0742 - 23ms/epoch - 23ms/step
# Epoch 89/100
# 1/1 - 0s - loss: 0.0727 - 18ms/epoch - 18ms/step
# Epoch 90/100
# 1/1 - 0s - loss: 0.0711 - 35ms/epoch - 35ms/step
# Epoch 91/100
# 1/1 - 0s - loss: 0.0696 - 24ms/epoch - 24ms/step
# Epoch 92/100
# 1/1 - 0s - loss: 0.0680 - 58ms/epoch - 58ms/step
# Epoch 93/100
# 1/1 - 0s - loss: 0.0664 - 20ms/epoch - 20ms/step
# Epoch 94/100
# 1/1 - 0s - loss: 0.0649 - 14ms/epoch - 14ms/step
# Epoch 95/100
# 1/1 - 0s - loss: 0.0634 - 34ms/epoch - 34ms/step
# Epoch 96/100
# 1/1 - 0s - loss: 0.0618 - 49ms/epoch - 49ms/step
# Epoch 97/100
# 1/1 - 0s - loss: 0.0603 - 30ms/epoch - 30ms/step
# Epoch 98/100
# 1/1 - 0s - loss: 0.0587 - 19ms/epoch - 19ms/step
# Epoch 99/100
# 1/1 - 0s - loss: 0.0571 - 57ms/epoch - 57ms/step
# Epoch 100/100
# 1/1 - 0s - loss: 0.0556 - 74ms/epoch - 74ms/step
# 1/1 [==============================] - 1s 744ms/step
# MAPE :
# 3.2408539205789566
# RMSE :
# 0.58594304
# MAE :
# 0.524271
# MAPE :
# 11.111348867416382
# RMSE :
# 1.150048
# MAE :
# 1.0212011
# MAPE :
# 1.8717709928750992
# RMSE :
# 0.5659783
# MAE :
# 0.471416
# MAPE :
# 1.0500111617147923
# RMSE :
# 0.02263422
# MAE :
# 0.020537913
# MAPE :
# 4.152848571538925
# RMSE :
# 0.5848078
# MAE :
# 0.5654037
# [[19.25294479726885, 8.048161731348335, 26.87627855928776, 2.2340634269509745, 12.964480437159809, 10.457907206580028, 11.073041313330867]]

# %%
intensity='MGI'
plot='G8'
po(plot,intensity)
plot='G11'
po(plot,intensity)
plot='G16'
po(plot,intensity)
# Out:
# ---------------分割线-------------------
# G8 MGI
# -------------------------------
# Epoch 1/100
# 1/1 - 6s - loss: 0.3767 - 6s/epoch - 6s/step
# Epoch 2/100
# 1/1 - 0s - loss: 0.3725 - 22ms/epoch - 22ms/step
# Epoch 3/100
# 1/1 - 0s - loss: 0.3685 - 40ms/epoch - 40ms/step
# Epoch 4/100
# 1/1 - 0s - loss: 0.3644 - 44ms/epoch - 44ms/step
# Epoch 5/100
# 1/1 - 0s - loss: 0.3602 - 39ms/epoch - 39ms/step
# Epoch 6/100
# 1/1 - 0s - loss: 0.3556 - 38ms/epoch - 38ms/step
# Epoch 7/100
# 1/1 - 0s - loss: 0.
ms/step
# Epoch 71/100
# 1/1 - 0s - loss: 0.1008 - 17ms/epoch - 17ms/step
# Epoch 72/100
# 1/1 - 0s - loss: 0.0995 - 22ms/epoch - 22ms/step
# Epoch 73/100
# 1/1 - 0s - loss: 0.0982 - 15ms/epoch - 15ms/step
# Epoch 74/100
# 1/1 - 0s - loss: 0.0971 - 25ms/epoch - 25ms/step
# Epoch 75/100
# 1/1 - 0s - loss: 0.0961 - 15ms/epoch - 15ms/step
# Epoch 76/100
# 1/1 - 0s - loss: 0.0951 - 31ms/epoch - 31ms/step
# Epoch 77/100
# 1/1 - 0s - loss: 0.0942 - 23ms/epoch - 23ms/step
# Epoch 78/100
# 1/1 - 0s - loss: 0.0934 - 40ms/epoch - 40ms/step
# Epoch 79/100
# 1/1 - 0s - loss: 0.0925 - 17ms/epoch - 17ms/step
# Epoch 80/100
# 1/1 - 0s - loss: 0.0917 - 15ms/epoch - 15ms/step
# Epoch 81/100
# 1/1 - 0s - loss: 0.0908 - 24ms/epoch - 24ms/step
# Epoch 82/100
# 1/1 - 0s - loss: 0.0899 - 23ms/epoch - 23ms/step
# Epoch 83/100
# 1/1 - 0s - loss: 0.0891 - 20ms/epoch - 20ms/step
# Epoch 84/100
# 1/1 - 0s - loss: 0.0882 - 16ms/epoch - 16ms/step
# Epoch 85/100
# 1/1 - 0s - loss: 0.0873 - 15ms/epoch - 15ms/step
# Epoch 86/100
# 1/1 - 0s - loss: 0.0863 - 19ms/epoch - 19ms/step
# Epoch 87/100
# 1/1 - 0s - loss: 0.0854 - 20ms/epoch - 20ms/step
# Epoch 88/100
# 1/1 - 0s - loss: 0.0846 - 15ms/epoch - 15ms/step
# Epoch 89/100
# 1/1 - 0s - loss: 0.0837 - 17ms/epoch - 17ms/step
# Epoch 90/100
# 1/1 - 0s - loss: 0.0828 - 19ms/epoch - 19ms/step
# Epoch 91/100
# 1/1 - 0s - loss: 0.0819 - 21ms/epoch - 21ms/step
# Epoch 92/100
# 1/1 - 0s - loss: 0.0811 - 17ms/epoch - 17ms/step
# Epoch 93/100
# 1/1 - 0s - loss: 0.0802 - 20ms/epoch - 20ms/step
# Epoch 94/100
# 1/1 - 0s - loss: 0.0794 - 20ms/epoch - 20ms/step
# Epoch 95/100
# 1/1 - 0s - loss: 0.0786 - 52ms/epoch - 52ms/step
# Epoch 96/100
# 1/1 - 0s - loss: 0.0778 - 33ms/epoch - 33ms/step
# Epoch 97/100
# 1/1 - 0s - loss: 0.0771 - 31ms/epoch - 31ms/step
# Epoch 98/100
# 1/1 - 0s - loss: 0.0764 - 29ms/epoch - 29ms/step
# Epoch 99/100
# 1/1 - 0s - loss: 0.0757 - 43ms/epoch - 43ms/step
# Epoch 100/100
# 1/1 - 0s - loss: 0.0750 - 38ms/epoch - 38ms/step
# 1/1 [==============================] - 1s 578ms/step
# MAPE :
# 2.739495038986206
# RMSE :
# 0.45909458
# MAE :
# 0.38942194
# MAPE :
# 17.42599457502365
# RMSE :
# 1.1914617
# MAE :
# 1.0124047
# MAPE :
# 6.081389635801315
# RMSE :
# 1.5493557
# MAE :
# 1.2608218
# MAPE :
# 1.342236716300249
# RMSE :
# 0.031853464
# MAE :
# 0.024534374
# MAPE :
# 7.471196353435516
# RMSE :
# 1.0973114
# MAE :
# 0.89921165
# [[14.228622959836384, 4.263589298199023, 18.831455874936605, 1.8516356034905495, 10.146903566745777, 10.618961968697064, 11.200693861466524]]
# ---------------分割线-------------------
# G16 MGI
# -------------------------------
# Epoch 1/100
# 1/1 - 4s - loss: 0.5144 - 4s/epoch - 4s/step
# Epoch 2/100
# 1/1 - 0s - loss: 0.5083 - 18ms/epoch - 18ms/step
# Epoch 3/100
# 1/1 - 0s - loss: 0.5023 - 17ms/epoch - 17ms/step
# Epoch 4/100
# 1/1 - 0s - loss: 0.4965 - 19ms/epoch - 19ms/step
# Epoch 5/100
# 1/1 - 0s - loss: 0.4905 - 33ms/epoch - 33ms/step
# Epoch 6/100
# 1/1 - 0s - loss: 0.4840 - 42ms/epoch - 42ms/step
# Epoch 7/100
# 1/1 - 0s - loss: 0.4770 - 55ms/epoch - 55ms/step
# Epoch 8/100
# 1/1 - 0s - loss: 0.4693 - 19ms/epoch - 19ms/step
# Epoch 9/100
# 1/1 - 0s - loss: 0.4609 - 37ms/epoch - 37ms/step
# Epoch 10/100
# 1/1 - 0s - loss: 0.4517 - 39ms/epoch - 39ms/step
# Epoch 11/100
# 1/1 - 0s - loss: 0.4416 - 50ms/epoch - 50ms/step
# Epoch 12/100
# 1/1 - 0s - loss: 0.4305 - 21ms/epoch - 21ms/step
# Epoch 13/100
# 1/1 - 0s - loss: 0.4185 - 31ms/epoch - 31ms/step
# Epoch 14/100
# 1/1 - 0s - loss: 0.4053 - 26ms/epoch - 26ms/step
# Epoch 15/100
# 1/1 - 0s - loss: 0.3910 - 32ms/epoch - 32ms/step
# Epoch 16/100
# 1/1 - 0s - loss: 0.3756 - 16ms/epoch - 16ms/step
# Epoch 17/100
# 1/1 - 0s - loss: 0.3590 - 24ms/epoch - 24ms/step
# Epoch 18/100
# 1/1 - 0s - loss: 0.3412 - 16ms/epoch - 16ms/step
# Epoch 19/100
# 1/1 - 0s - loss: 0.3223 - 24ms/epoch - 24ms/step
# Epoch 20/100
# 1/1 - 0s - loss: 0.3023 - 17ms/epoch - 17ms/step
# Epoch 21/100
# 1/1 - 0s - loss: 0.2814 - 15ms/epoch - 15ms/step
# Epoch 22/100
# 1/1 - 0s - loss: 0.2600 - 22ms/epoch - 22ms/step
# Epoch 23/100
# 1/1 - 0s - loss: 0.2383 - 20ms/epoch - 20ms/step
# Epoch 24/100
# 1/1 - 0s - loss: 0.2169 - 17ms/epoch - 17ms/step
# Epoch 25/100
# 1/1 - 0s - loss: 0.1966 - 17ms/epoch - 17ms/step
# Epoch 26/100
# 1/1 - 0s - loss: 0.1782 - 16ms/epoch - 16ms/step
# Epoch 27/100
# 1/1 - 0s - loss: 0.1628 - 21ms/epoch - 21ms/step
# Epoch 28/100
# 1/1 - 0s - loss: 0.1516 - 14ms/epoch - 14ms/step
# Epoch 29/100
# 1/1 - 0s - loss: 0.1454 - 19ms/epoch - 19ms/step
# Epoch 30/100
# 1/1 - 0s - loss: 0.1445 - 22ms/epoch - 22ms/step
# Epoch 31/100
# 1/1 - 0s - loss: 0.1474 - 22ms/epoch - 22ms/step
# Epoch 32/100
# 1/1 - 0s - loss: 0.1519 - 16ms/epoch - 16ms/step
# Epoch 33/100
# 1/1 - 0s - loss: 0.1552 - 15ms/epoch - 15ms/step
# Epoch 34/100
# 1/1 - 0s - loss: 0.1555 - 25ms/epoch - 25ms/step
# Epoch 35/100
# 1/1 - 0s - loss: 0.1525 - 27ms/epoch - 27ms/step
# Epoch 36/100
# 1/1 - 0s - loss: 0.1468 - 32ms/epoch - 32ms/step
# Epoch 37/100
# 1/1 - 0s - loss: 0.1398 - 19ms/epoch - 19ms/step
# Epoch 38/100
# 1/1 - 0s - loss: 0.1326 - 15ms/epoch - 15ms/step
# Epoch 39/100
# 1/1 - 0s - loss: 0.1264 - 46ms/epoch - 46ms/step
# Epoch 40/100
# 1/1 - 0s - loss: 0.1215 - 17ms/epoch - 17ms/step
# Epoch 41/100
# 1/1 - 0s - loss: 0.1182 - 19ms/epoch - 19ms/step
# Epoch 42/100
# 1/1 - 0s - loss: 0.1161 - 21ms/epoch - 21ms/step
# Epoch 43/100
# 1/1 - 0s - loss: 0.1151 - 19ms/epoch - 19ms/step
# Epoch 44/100
# 1/1 - 0s - loss: 0.1146 - 16ms/epoch - 16ms/step
# Epoch 45/100
# 1/1 - 0s - loss: 0.1143 - 18ms/epoch - 18ms/step
# Epoch 46/100
# 1/1 - 0s - loss: 0.1140 - 24ms/epoch - 24ms/step
# Epoch 47/100
# 1/1 - 0s - loss: 0.1133 - 16ms/epoch - 16ms/step
# Epoch 48/100
# 1/1 - 0s - loss: 0.1123 - 26ms/epoch - 26ms/step
# Epoch 49/100
# 1/1 - 0s - loss: 0.1109 - 17ms/epoch - 17ms/step
# Epoch 50/100
# 1/1 - 0s - loss: 0.1092 - 47ms/epoch - 47ms/step
# Epoch 51/100
# 1/1 - 0s - loss: 0.1071 - 20ms/epoch - 20ms/step
# Epoch 52/100
# 1/1 - 0s - loss: 0.1049 - 20ms/epoch - 20ms/step
# Epoch 53/100
# 1/1 - 0s - loss: 0.1026 - 61ms/epoch - 61ms/step
# Epoch 54/100
# 1/1 - 0s - loss: 0.1003 - 20ms/epoch - 20ms/step
# Epoch 55/100
# 1/1 - 0s - loss: 0.0982 - 45ms/epoch - 45ms/step
# Epoch 56/100
# 1/1 - 0s - loss: 0.0964 - 14ms/epoch - 14ms/step
# Epoch 57/100
# 1/1 - 0s - loss: 0.0948 - 15ms/epoch - 15ms/step
# Epoch 58/100
# 1/1 - 0s - loss: 0.0933 - 20ms/epoch - 20ms/step
# Epoch 59/100
# 1/1 - 0s - loss: 0.0920 - 16ms/epoch - 16ms/step
# Epoch 60/100
# 1/1 - 0s - loss: 0.0907 - 52ms/epoch - 52ms/step
# Epoch 61/100
# 1/1 - 0s - loss: 0.0894 - 15ms/epoch - 15ms/step
# Epoch 62/100
# 1/1 - 0s - loss: 0.0879 - 45ms/epoch - 45ms/step
# Epoch 63/100
# 1/1 - 0s - loss: 0.0862 - 15ms/epoch - 15ms/step
# Epoch 64/100
# 1/1 - 0s - loss: 0.0843 - 16ms/epoch - 16ms/step
# Epoch 65/100
# 1/1 - 0s - loss: 0.0824 - 17ms/epoch - 17ms/step
# Epoch 66/100
# 1/1 - 0s - loss: 0.0804 - 21ms/epoch - 21ms/step
# Epoch 67/100
# 1/1 - 0s - loss: 0.0784 - 19ms/epoch - 19ms/step
# Epoch 68/100
# 1/1 - 0s - loss: 0.0765 - 20ms/epoch - 20ms/step
# Epoch 69/100
# 1/1 - 0s - loss: 0.0746 - 22ms/epoch - 22ms/step
# Epoch 70/100
# 1/1 - 0s - loss: 0.0729 - 18ms/epoch - 18ms/step
# Epoch 71/100
# 1/1 - 0s - loss: 0.0711 - 19ms/epoch - 19ms/step
# Epoch 72/100
# 1/1 - 0s - loss: 0.0692 - 13ms/epoch - 13ms/step
# Epoch 73/100
# 1/1 - 0s - loss: 0.0673 - 22ms/epoch - 22ms/step
# Epoch 74/100
# 1/1 - 0s - loss: 0.0653 - 18ms/epoch - 18ms/step
# Epoch 75/100
# 1/1 - 0s - loss: 0.0633 - 16ms/epoch - 16ms/step
# Epoch 76/100
# 1/1 - 0s - loss: 0.0611 - 17ms/epoch - 17ms/step
# Epoch 77/100
# 1/1 - 0s - loss: 0.0590 - 22ms/epoch - 22ms/step
# Epoch 78/100
# 1/1 - 0s - loss: 0.0568 - 18ms/epoch - 18ms/step
# Epoch 79/100
# 1/1 - 0s - loss: 0.0546 - 18ms/epoch - 18ms/step
# Epoch 80/100
# 1/1 - 0s - loss: 0.0525 - 15ms/epoch - 15ms/step
# Epoch 81/100
# 1/1 - 0s - loss: 0.0504 - 15ms/epoch - 15ms/step
# Epoch 82/100
# 1/1 - 0s - loss: 0.0483 - 22ms/epoch - 22ms/step
# Epoch 83/100
# 1/1 - 0s - loss: 0.0462 - 18ms/epoch - 18ms/step
# Epoch 84/100
# 1/1 - 0s - loss: 0.0442 - 19ms/epoch - 19ms/step
# Epoch 85/100
# 1/1 - 0s - loss: 0.0422 - 17ms/epoch - 17ms/step
# Epoch 86/100
# 1/1 - 0s - loss: 0.0403 - 18ms/epoch - 18ms/step
# Epoch 87/100
# 1/1 - 0s - loss: 0.0384 - 19ms/epoch - 19ms/step
# Epoch 88/100
# 1/1 - 0s - loss: 0.0367 - 16ms/epoch - 16ms/step
# Epoch 89/100
# 1/1 - 0s - loss: 0.0350 - 16ms/epoch - 16ms/step
# Epoch 90/100
# 1/1 - 0s - loss: 0.0334 - 15ms/epoch - 15ms/step
# Epoch 91/100
# 1/1 - 0s - loss: 0.0320 - 16ms/epoch - 16ms/step
# Epoch 92/100
# 1/1 - 0s - loss: 0.0306 - 23ms/epoch - 23ms/step
# Epoch 93/100
# 1/1 - 0s - loss: 0.0294 - 18ms/epoch - 18ms/step
# Epoch 94/100
# 1/1 - 0s - loss: 0.0282 - 13ms/epoch - 13ms/step
# Epoch 95/100
# 1/1 - 0s - loss: 0.0271 - 28ms/epoch - 28ms/step
# Epoch 96/100
# 1/1 - 0s - loss: 0.0261 - 32ms/epoch - 32ms/step
# Epoch 97/100
# 1/1 - 0s - loss: 0.0252 - 52ms/epoch - 52ms/step
# Epoch 98/100
# 1/1 - 0s - loss: 0.0243 - 43ms/epoch - 43ms/step
# Epoch 99/100
# 1/1 - 0s - loss: 0.0235 - 60ms/epoch - 60ms/step
# Epoch 100/100
# 1/1 - 0s - loss: 0.0227 - 17ms/epoch - 17ms/step
# 1/1 [==============================] - 1s 657ms/step
# MAPE :
# 2.436959184706211
# RMSE :
# 0.37960926
# MAE :
# 0.3348868
# MAPE :
# 3.9909183979034424
# RMSE :
# 0.5025139
# MAE :
# 0.4038899
# MAPE :
# 0.48931026831269264
# RMSE :
# 0.14498703
# MAE :
# 0.1189599
# MAPE :
# 2.0248986780643463
# RMSE :
# 0.036388863
# MAE :
# 0.032197535
# MAPE :
# 5.36380335688591
# RMSE :
# 0.94946927
# MAE :
# 0.82860136
# [[15.014662155131454, 11.37957985338598, 25.835291003793273, 1.6333106407215008, 18.603074338670346, 11.140326004275652, 11.800641587267004]]

# %%
intensity='HGI'
plot='G9'
po(plot,intensity)
plot='G13'
po(plot,intensity)
plot='G20'
po(plot,intensity)
# Out:
# ---------------分割线-------------------
# G9 HGI
# -------------------------------
# Epoch 1/100
# 1/1 - 5s - loss: 0.3245 - 5s/epoch - 5s/step
# Epoch 2/100
# 1/1 - 0s - loss: 0.3210 - 15ms/epoch - 15ms/step
# Epoch 3/100
# 1/1 - 0s - loss: 0.3176 - 16ms/epoch - 16ms/step
# Epoch 4/100
# 1/1 - 0s - loss: 0.3142 - 14ms/epoch - 14ms/step
# Epoch 5/100
# 1/1 - 0s - loss: 0.3106 - 16ms/epoch - 16ms/step
# Epoch 6/100
# 1/1 - 0s - loss: 0.
ms/step
# Epoch 99/100
# 1/1 - 0s - loss: 0.0410 - 23ms/epoch - 23ms/step
# Epoch 100/100
# 1/1 - 0s - loss: 0.0406 - 18ms/epoch - 18ms/step
# 1/1 [==============================] - 1s 807ms/step
# MAPE :
# 4.875402897596359
# RMSE :
# 0.7396757
# MAE :
# 0.7031362
# MAPE :
# 6.882854551076889
# RMSE :
# 0.37232766
# MAE :
# 0.34127748
# MAPE :
# 1.1715283617377281
# RMSE :
# 0.27811682
# MAE :
# 0.24979258
# MAPE :
# 8.992860466241837
# RMSE :
# 0.16887416
# MAE :
# 0.15057233
# MAPE :
# 5.805749818682671
# RMSE :
# 0.785624
# MAE :
# 0.73326135
# [[17.725218712032394, 4.921751056056162, 20.869935195766768, 2.3677717388622312, 10.968340885042318, 11.41659651232712, 12.026062997659542]]
# ---------------分割线-------------------
# G13 HGI
# -------------------------------
# Epoch 1/100
# 1/1 - 5s - loss: 0.3057 - 5s/epoch - 5s/step
# Epoch 2/100
# 1/1 - 0s - loss: 0.3023 - 17ms/epoch - 17ms/step
# Epoch 3/100
# 1/1 - 0s - loss: 0.2991 - 16ms/epoch - 16ms/step
# Epoch 4/100
# 1/1 - 0s - loss: 0.2959 - 25ms/epoch - 25ms/step
# Epoch 5/100
# 1/1 - 0s - loss: 0.2924 - 18ms/epoch - 18ms/step
# Epoch 6/100
# 1/1 - 0s - loss: 0.2887 - 20ms/epoch - 20ms/step
# Epoch 7/100
# 1/1 - 0s - loss: 0.2847 - 13ms/epoch - 13ms/step
# Epoch 8/100
# 1/1 - 0s - loss: 0.2803 - 62ms/epoch - 62ms/step
# Epoch 9/100
# 1/1 - 0s - loss: 0.2755 - 18ms/epoch - 18ms/step
# Epoch 10/100
# 1/1 - 0s - loss: 0.2703 - 24ms/epoch - 24ms/step
# Epoch 11/100
# 1/1 - 0s - loss: 0.2646 - 23ms/epoch - 23ms/step
# Epoch 12/100
# 1/1 - 0s - loss: 0.2584 - 19ms/epoch - 19ms/step
# Epoch 13/100
# 1/1 - 0s - loss: 0.2517 - 25ms/epoch - 25ms/step
# Epoch 14/100
# 1/1 - 0s - loss: 0.2443 - 19ms/epoch - 19ms/step
# Epoch 15/100
# 1/1 - 0s - loss: 0.2364 - 21ms/epoch - 21ms/step
# Epoch 16/100
# 1/1 - 0s - loss: 0.2279 - 16ms/epoch - 16ms/step
# Epoch 17/100
# 1/1 - 0s - loss: 0.2187 - 27ms/epoch - 27ms/step
# Epoch 18/100
# 1/1 - 0s - loss: 0.2089 - 18ms/epoch - 18ms/step
# Epoch 19/100
# 1/1 - 0s - loss: 0.1986 - 17ms/epoch - 17ms/step
# Epoch 20/100
# 1/1 - 0s - loss: 0.1878 - 18ms/epoch - 18ms/step
# Epoch 21/100
# 1/1 - 0s - loss: 0.1766 - 20ms/epoch - 20ms/step
# Epoch 22/100
# 1/1 - 0s - loss: 0.1653 - 29ms/epoch - 29ms/step
# Epoch 23/100
# 1/1 - 0s - loss: 0.1539 - 29ms/epoch - 29ms/step
# Epoch 24/100
# 1/1 - 0s - loss: 0.1429 - 33ms/epoch - 33ms/step
# Epoch 25/100
# 1/1 - 0s - loss: 0.1325 - 29ms/epoch - 29ms/step
# Epoch 26/100
# 1/1 - 0s - loss: 0.1234 - 19ms/epoch - 19ms/step
# Epoch 27/100
# 1/1 - 0s - loss: 0.1160 - 20ms/epoch - 20ms/step
# Epoch 28/100
# 1/1 - 0s - loss: 0.1107 - 23ms/epoch - 23ms/step
# Epoch 29/100
# 1/1 - 0s - loss: 0.1080 - 15ms/epoch - 15ms/step
# Epoch 30/100
# 1/1 - 0s - loss: 0.1075 - 24ms/epoch - 24ms/step
# Epoch 31/100
# 1/1 - 0s - loss: 0.1086 - 23ms/epoch - 23ms/step
# Epoch 32/100
# 1/1 - 0s - loss: 0.1101 - 26ms/epoch - 26ms/step
# Epoch 33/100
# 1/1 - 0s - loss: 0.1108 - 19ms/epoch - 19ms/step
# Epoch 34/100
# 1/1 - 0s - loss: 0.1101 - 31ms/epoch - 31ms/step
# Epoch 35/100
# 1/1 - 0s - loss: 0.1079 - 33ms/epoch - 33ms/step
# Epoch 36/100
# 1/1 - 0s - loss: 0.1046 - 35ms/epoch - 35ms/step
# Epoch 37/100
# 1/1 - 0s - loss: 0.1008 - 31ms/epoch - 31ms/step
# Epoch 38/100
# 1/1 - 0s - loss: 0.0971 - 19ms/epoch - 19ms/step
# Epoch 39/100
# 1/1 - 0s - loss: 0.0937 - 37ms/epoch - 37ms/step
# Epoch 40/100
# 1/1 - 0s - loss: 0.0910 - 29ms/epoch - 29ms/step
# Epoch 41/100
# 1/1 - 0s - loss: 0.0889 - 49ms/epoch - 49ms/step
# Epoch 42/100
# 1/1 - 0s - loss: 0.0874 - 36ms/epoch - 36ms/step
# Epoch 43/100
# 1/1 - 0s - loss: 0.0863 - 18ms/epoch - 18ms/step
# Epoch 44/100
# 1/1 - 0s - loss: 0.0855 - 38ms/epoch - 38ms/step
# Epoch 45/100
# 1/1 - 0s - loss: 0.0849 - 25ms/epoch - 25ms/step
# Epoch 46/100
# 1/1 - 0s - loss: 0.0842 - 28ms/epoch - 28ms/step
# Epoch 47/100
# 1/1 - 0s - loss: 0.0834 - 22ms/epoch - 22ms/step
# Epoch 48/100
# 1/1 - 0s - loss: 0.0825 - 23ms/epoch - 23ms/step
# Epoch 49/100
# 1/1 - 0s - loss: 0.0815 - 17ms/epoch - 17ms/step
# Epoch 50/100
# 1/1 - 0s - loss: 0.0804 - 28ms/epoch - 28ms/step
# Epoch 51/100
# 1/1 - 0s - loss: 0.0792 - 17ms/epoch - 17ms/step
# Epoch 52/100
# 1/1 - 0s - loss: 0.0779 - 50ms/epoch - 50ms/step
# Epoch 53/100
# 1/1 - 0s - loss: 0.0766 - 21ms/epoch - 21ms/step
# Epoch 54/100
# 1/1 - 0s - loss: 0.0753 - 27ms/epoch - 27ms/step
# Epoch 55/100
# 1/1 - 0s - loss: 0.0742 - 15ms/epoch - 15ms/step
# Epoch 56/100
# 1/1 - 0s - loss: 0.0731 - 30ms/epoch - 30ms/step
# Epoch 57/100
# 1/1 - 0s - loss: 0.0722 - 49ms/epoch - 49ms/step
# Epoch 58/100
# 1/1 - 0s - loss: 0.0713 - 15ms/epoch - 15ms/step
# Epoch 59/100
# 1/1 - 0s - loss: 0.0705 - 16ms/epoch - 16ms/step
# Epoch 60/100
# 1/1 - 0s - loss: 0.0698 - 34ms/epoch - 34ms/step
# Epoch 61/100
# 1/1 - 0s - loss: 0.0690 - 31ms/epoch - 31ms/step
# Epoch 62/100
# 1/1 - 0s - loss: 0.0682 - 39ms/epoch - 39ms/step
# Epoch 63/100
# 1/1 - 0s - loss: 0.0673 - 23ms/epoch - 23ms/step
# Epoch 64/100
# 1/1 - 0s - loss: 0.0664 - 19ms/epoch - 19ms/step
# Epoch 65/100
# 1/1 - 0s - loss: 0.0655 - 16ms/epoch - 16ms/step
# Epoch 66/100
# 1/1 - 0s - loss: 0.0646 - 20ms/epoch - 20ms/step
# Epoch 67/100
# 1/1 - 0s - loss: 0.0637 - 19ms/epoch - 19ms/step
# Epoch 68/100
# 1/1 - 0s - loss: 0.0629 - 16ms/epoch - 16ms/step
# Epoch 69/100
# 1/1 - 0s - loss: 0.0621 - 16ms/epoch - 16ms/step
# Epoch 70/100
# 1/1 - 0s - loss: 0.0613 - 48ms/epoch - 48ms/step
# Epoch 71/100
# 1/1 - 0s - loss: 0.0606 - 22ms/epoch - 22ms/step
# Epoch 72/100
# 1/1 - 0s - loss: 0.0599 - 15ms/epoch - 15ms/step
# Epoch 73/100
# 1/1 - 0s - loss: 0.0593 - 34ms/epoch - 34ms/step
# Epoch 74/100
# 1/1 - 0s - loss: 0.0587 - 15ms/epoch - 15ms/step
# Epoch 75/100
# 1/1 - 0s - loss: 0.0580 - 33ms/epoch - 33ms/step
# Epoch 76/100
# 1/1 - 0s - loss: 0.0575 - 30ms/epoch - 30ms/step
# Epoch 77/100
# 1/1 - 0s - loss: 0.0569 - 37ms/epoch - 37ms/step
# Epoch 78/100
# 1/1 - 0s - loss: 0.0563 - 36ms/epoch - 36ms/step
# Epoch 79/100
# 1/1 - 0s - loss: 0.0557 - 54ms/epoch - 54ms/step
# Epoch 80/100
# 1/1 - 0s - loss: 0.0552 - 31ms/epoch - 31ms/step
# Epoch 81/100
# 1/1 - 0s - loss: 0.0547 - 32ms/epoch - 32ms/step
# Epoch 82/100
# 1/1 - 0s - loss: 0.0543 - 31ms/epoch - 31ms/step
# Epoch 83/100
# 1/1 - 0s - loss: 0.0538 - 17ms/epoch - 17ms/step
# Epoch 84/100
# 1/1 - 0s - loss: 0.0534 - 17ms/epoch - 17ms/step
# Epoch 85/100
# 1/1 - 0s - loss: 0.0529 - 14ms/epoch - 14ms/step
# Epoch 86/100
# 1/1 - 0s - loss: 0.0525 - 27ms/epoch - 27ms/step
# Epoch 87/100
# 1/1 - 0s - loss: 0.0521 - 24ms/epoch - 24ms/step
# Epoch 88/100
# 1/1 - 0s - loss: 0.0517 - 31ms/epoch - 31ms/step
# Epoch 89/100
# 1/1 - 0s - loss: 0.0512 - 29ms/epoch - 29ms/step
# Epoch 90/100
# 1/1 - 0s - loss: 0.0508 - 34ms/epoch - 34ms/step
# Epoch 91/100
# 1/1 - 0s - loss: 0.0504 - 32ms/epoch - 32ms/step
# Epoch 92/100
# 1/1 - 0s - loss: 0.0500 - 21ms/epoch - 21ms/step
# Epoch 93/100
# 1/1 - 0s - loss: 0.0496 - 21ms/epoch - 21ms/step
# Epoch 94/100
# 1/1 - 0s - loss: 0.0492 - 27ms/epoch - 27ms/step
# Epoch 95/100
# 1/1 - 0s - loss: 0.0488 - 47ms/epoch - 47ms/step
# Epoch 96/100
# 1/1 - 0s - loss: 0.0484 - 21ms/epoch - 21ms/step
# Epoch 97/100
# 1/1 - 0s - loss: 0.0479 - 17ms/epoch - 17ms/step
# Epoch 98/100
# 1/1 - 0s - loss: 0.0475 - 26ms/epoch - 26ms/step
# Epoch 99/100
# 1/1 - 0s - loss: 0.0471 - 16ms/epoch - 16ms/step
# Epoch 100/100
# 1/1 - 0s - loss: 0.0467 - 16ms/epoch - 16ms/step
# 1/1 [==============================] - 1s 727ms/step
# MAPE :
# 3.8421355187892914
# RMSE :
# 0.7008701
# MAE :
# 0.60058546
# MAPE :
# 13.003265857696533
# RMSE :
# 0.70652187
# MAE :
# 0.58040863
# MAPE :
# 0.9494615718722343
# RMSE :
# 0.23040351
# MAE :
# 0.19761181
# MAPE :
# 3.0246295034885406
# RMSE :
# 0.08056497
# MAE :
# 0.06022331
# MAPE :
# 5.159730091691017
# RMSE :
# 0.6288404
# MAE :
# 0.55252504
# [[17.813405804679558, 4.717934448271964, 21.061602477937566, 2.196547566725173, 11.12428142282762, 9.388235885509635, 10.121652090233]]
# ---------------分割线-------------------
# G20 HGI
# -------------------------------
# Epoch 1/100
# 1/1 - 5s - loss: 0.4063 - 5s/epoch - 5s/step
# Epoch 2/100
# 1/1 - 0s - loss: 0.4024 - 17ms/epoch - 17ms/step
# Epoch 3/100
# 1/1 - 0s - loss: 0.3986 - 16ms/epoch - 16ms/step
# Epoch 4/100
# 1/1 - 0s - loss: 0.3948 - 18ms/epoch - 18ms/step
# Epoch 5/100
# 1/1 - 0s - loss: 0.3910 - 31ms/epoch - 31ms/step
# Epoch 6/100
# 1/1 - 0s - loss: 0.3868 - 62ms/epoch - 62ms/step
# Epoch 7/100
# 1/1 - 0s - loss: 0.3823 - 20ms/epoch - 20ms/step
# Epoch 8/100
# 1/1 - 0s - loss: 0.3773 - 23ms/epoch - 23ms/step
# Epoch 9/100
# 1/1 - 0s - loss: 0.3718 - 42ms/epoch - 42ms/step
# Epoch 10/100
# 1/1 - 0s - loss: 0.3659 - 19ms/epoch - 19ms/step
# Epoch 11/100
# 1/1 - 0s - loss: 0.3594 - 28ms/epoch - 28ms/step
# Epoch 12/100
# 1/1 - 0s - loss: 0.3522 - 23ms/epoch - 23ms/step
# Epoch 13/100
# 1/1 - 0s - loss: 0.3444 - 54ms/epoch - 54ms/step
# Epoch 14/100
# 1/1 - 0s - loss: 0.3360 - 35ms/epoch - 35ms/step
# Epoch 15/100
# 1/1 - 0s - loss: 0.3268 - 21ms/epoch - 21ms/step
# Epoch 16/100
# 1/1 - 0s - loss: 0.3169 - 16ms/epoch - 16ms/step
# Epoch 17/100
# 1/1 - 0s - loss: 0.3064 - 48ms/epoch - 48ms/step
# Epoch 18/100
# 1/1 - 0s - loss: 0.2951 - 25ms/epoch - 25ms/step
# Epoch 19/100
# 1/1 - 0s - loss: 0.2833 - 21ms/epoch - 21ms/step
# Epoch 20/100
# 1/1 - 0s - loss: 0.2709 - 52ms/epoch - 52ms/step
# Epoch 21/100
# 1/1 - 0s - loss: 0.2583 - 43ms/epoch - 43ms/step
# Epoch 22/100
# 1/1 - 0s - loss: 0.2457 - 36ms/epoch - 36ms/step
# Epoch 23/100
# 1/1 - 0s - loss: 0.2333 - 44ms/epoch - 44ms/step
# Epoch 24/100
# 1/1 - 0s - loss: 0.2218 - 55ms/epoch - 55ms/step
# Epoch 25/100
# 1/1 - 0s - loss: 0.2116 - 44ms/epoch - 44ms/step
# Epoch 26/100
# 1/1 - 0s - loss: 0.2035 - 28ms/epoch - 28ms/step
# Epoch 27/100
# 1/1 - 0s - loss: 0.1979 - 17ms/epoch - 17ms/step
# Epoch 28/100
# 1/1 - 0s - loss: 0.1951 - 18ms/epoch - 18ms/step
# Epoch 29/100
# 1/1 - 0s - loss: 0.1946 - 17ms/epoch - 17ms/step
# Epoch 30/100
# 1/1 - 0s - loss: 0.1953 - 17ms/epoch - 17ms/step
# Epoch 31/100
# 1/1 - 0s - loss: 0.1957 - 15ms/epoch - 15ms/step
# Epoch 32/100
# 1/1 - 0s - loss: 0.1949 - 17ms/epoch - 17ms/step
# Epoch 33/100
# 1/1 - 0s - loss: 0.1925 - 18ms/epoch - 18ms/step
# Epoch 34/100
# 1/1 - 0s - loss: 0.1886 - 18ms/epoch - 18ms/step
# Epoch 35/100
# 1/1 - 0s - loss: 0.1838 - 18ms/epoch - 18ms/step
# Epoch 36/100
# 1/1 - 0s - loss: 0.1788 - 33ms/epoch - 33ms/step
# Epoch 37/100
# 1/1 - 0s - loss: 0.1739 - 15ms/epoch - 15ms/step
# Epoch 38/100
# 1/1 - 0s - loss: 0.1696 - 32ms/epoch - 32ms/step
# Epoch 39/100
# 1/1 - 0s - loss: 0.1659 - 20ms/epoch - 20ms/step
# Epoch 40/100
# 1/1 - 0s - loss: 0.1629 - 18ms/epoch - 18ms/step
# Epoch 41/100
# 1/1 - 0s - loss: 0.1604 - 36ms/epoch - 36ms/step
# Epoch 42/100
# 1/1 - 0s - loss: 0.1582 - 16ms/epoch - 16ms/step
# Epoch 43/100
# 1/1 - 0s - loss: 0.1561 - 15ms/epoch - 15ms/step
# Epoch 44/100
# 1/1 - 0s - loss: 0.1542 - 43ms/epoch - 43ms/step
# Epoch 45/100
# 1/1 - 0s - loss: 0.1521 - 19ms/epoch - 19ms/step
# Epoch 46/100
# 1/1 - 0s - loss: 0.1499 - 20ms/epoch - 20ms/step
# Epoch 47/100
# 1/1 - 0s - loss: 0.1476 - 65ms/epoch - 65ms/step
# Epoch 48/100
# 1/1 - 0s - loss: 0.1451 - 42ms/epoch - 42ms/step
# Epoch 49/100
# 1/1 - 0s - loss: 0.1425 - 28ms/epoch - 28ms/step
# Epoch 50/100
# 1/1 - 0s - loss: 0.1398 - 29ms/epoch - 29ms/step
# Epoch 51/100
# 1/1 - 0s - loss: 0.1370 - 78ms/epoch - 78ms/step
# Epoch 52/100
# 1/1 - 0s - loss: 0.1342 - 23ms/epoch - 23ms/step
# Epoch 53/100
# 1/1 - 0s - loss: 0.1315 - 29ms/epoch - 29ms/step
# Epoch 54/100
# 1/1 - 0s - loss: 0.1288 - 24ms/epoch - 24ms/step
# Epoch 55/100
# 1/1 - 0s - loss: 0.1262 - 15ms/epoch - 15ms/step
# Epoch 56/100
# 1/1 - 0s - loss: 0.1237 - 22ms/epoch - 22ms/step
# Epoch 57/100
# 1/1 - 0s - loss: 0.1213 - 52ms/epoch - 52ms/step
# Epoch 58/100
# 1/1 - 0s - loss: 0.1189 - 36ms/epoch - 36ms/step
# Epoch 59/100
# 1/1 - 0s - loss: 0.1166 - 49ms/epoch - 49ms/step
# Epoch 60/100
# 1/1 - 0s - loss: 0.1142 - 31ms/epoch - 31ms/step
# Epoch 61/100
# 1/1 - 0s - loss: 0.1118 - 19ms/epoch - 19ms/step
# Epoch 62/100
# 1/1 - 0s - loss: 0.1094 - 36ms/epoch - 36ms/step
# Epoch 63/100
# 1/1 - 0s - loss: 0.1069 - 45ms/epoch - 45ms/step
# Epoch 64/100
# 1/1 - 0s - loss: 0.1044 - 15ms/epoch - 15ms/step
# Epoch 65/100
# 1/1 - 0s - loss: 0.1019 - 16ms/epoch - 16ms/step
# Epoch 66/100
# 1/1 - 0s - loss: 0.0995 - 16ms/epoch - 16ms/step
# Epoch 67/100
# 1/1 - 0s - loss: 0.0970 - 33ms/epoch - 33ms/step
# Epoch 68/100
# 1/1 - 0s - loss: 0.0946 - 43ms/epoch - 43ms/step
# Epoch 69/100
# 1/1 - 0s - loss: 0.0923 - 15ms/epoch - 15ms/step
# Epoch 70/100
# 1/1 - 0s - loss: 0.0901 - 22ms/epoch - 22ms/step
# Epoch 71/100
# 1/1 - 0s - loss: 0.0879 - 27ms/epoch - 27ms/step
# Epoch 72/100
# 1/1 - 0s - loss: 0.0857 - 21ms/epoch - 21ms/step
# Epoch 73/100
# 1/1 - 0s - loss: 0.0837 - 24ms/epoch - 24ms/step
# Epoch 74/100
# 1/1 - 0s - loss: 0.0817 - 34ms/epoch - 34ms/step
# Epoch 75/100
# 1/1 - 0s - loss: 0.0798 - 22ms/epoch - 22ms/step
# Epoch 76/100
# 1/1 - 0s - loss: 0.0779 - 19ms/epoch - 19ms/step
# Epoch 77/100
# 1/1 - 0s - loss: 0.0761 - 19ms/epoch - 19ms/step
# Epoch 78/100
# 1/1 - 0s - loss: 0.0742 - 18ms/epoch - 18ms/step
# Epoch 79/100
# 1/1 - 0s - loss: 0.0725 - 32ms/epoch - 32ms/step
# Epoch 80/100
# 1/1 - 0s - loss: 0.0707 - 23ms/epoch - 23ms/step
# Epoch 81/100
# 1/1 - 0s - loss: 0.0690 - 29ms/epoch - 29ms/step
# Epoch 82/100
# 1/1 - 0s - loss: 0.0673 - 23ms/epoch - 23ms/step
# Epoch 83/100
# 1/1 - 0s - loss: 0.0655 - 20ms/epoch - 20ms/step
# Epoch 84/100
# 1/1 - 0s - loss: 0.0638 - 20ms/epoch - 20ms/step
# Epoch 85/100
# 1/1 - 0s - loss: 0.0620 - 28ms/epoch - 28ms/step
# Epoch 86/100
# 1/1 - 0s - loss: 0.0601 - 19ms/epoch - 19ms/step
# Epoch 87/100
# 1/1 - 0s - loss: 0.0583 - 24ms/epoch - 24ms/step
# Epoch 88/100
# 1/1 - 0s - loss: 0.0564 - 31ms/epoch - 31ms/step
# Epoch 89/100
# 1/1 - 0s - loss: 0.0545 - 18ms/epoch - 18ms/step
# Epoch 90/100
# 1/1 - 0s - loss: 0.0527 - 19ms/epoch - 19ms/step
# Epoch 91/100
# 1/1 - 0s - loss: 0.0508 - 18ms/epoch - 18ms/step
# Epoch 92/100
# 1/1 - 0s - loss: 0.0489 - 17ms/epoch - 17ms/step
# Epoch 93/100
# 1/1 - 0s - loss: 0.0470 - 32ms/epoch - 32ms/step
# Epoch 94/100
# 1/1 - 0s - loss: 0.0451 - 49ms/epoch - 49ms/step
# Epoch 95/100
# 1/1 - 0s - loss: 0.0433 - 16ms/epoch - 16ms/step
# Epoch 96/100
# 1/1 - 0s - loss: 0.0415 - 23ms/epoch - 23ms/step
# Epoch 97/100
# 1/1 - 0s - loss: 0.0398 - 82ms/epoch - 82ms/step
# Epoch 98/100
# 1/1 - 0s - loss: 0.0382 - 54ms/epoch - 54ms/step
# Epoch 99/100
# 1/1 - 0s - loss: 0.0366 - 28ms/epoch - 28ms/step
# Epoch 100/100
# 1/1 - 0s - loss: 0.0351 - 73ms/epoch - 73ms/step
# 1/1 [==============================] - 1s 717ms/step
# MAPE :
# 2.03294325619936
# RMSE :
# 0.37865692
# MAE :
# 0.30945468
# MAPE :
# 5.152156576514244
# RMSE :
# 0.36877632
# MAE :
# 0.30453622
# MAPE :
# 2.9800472781062126
# RMSE :
# 0.81716365
# MAE :
# 0.70630455
# MAPE :
# 1.1934282258152962
# RMSE :
# 0.027768584
# MAE :
# 0.022249728
# MAPE :
# 2.0083315670490265
# RMSE :
# 0.27068925
# MAE :
# 0.2536633
# [[15.558039054583407, 5.976429545793715, 21.69644623675532, 1.98603728959704, 11.240485508535306, 10.140318701142514, 10.774637690060311]]
